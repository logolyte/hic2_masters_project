# %%
import pyranges
import pandas
import scanpy
import hdf5plugin
import anndata
import cellrank
import matplotlib
from matplotlib import pyplot
import cellrank
import numpy
import gseapy
import pygam
import seaborn

# %% [markdown]
# Packages required:
# - Pyranges
# - Pyfaidx

# %%
# Read annotation file
annotation = pyranges.read_gtf("RNA Sequencing Data/mm10 gencode reference/gencode.vM10.primary_assembly.annotation.gtf")
annotation
# Out:
# +--------------+------------+-------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature     | Start     | End       | +21   |
# | (category)   | (object)   | (object)    | (int64)   | (int64)   | ...   |
# |--------------+------------+-------------+-----------+-----------+-------|
# | GL456210.1   | ENSEMBL    | gene        | 123791    | 124928    | ...   |
# | GL456210.1   | ENSEMBL    | transcript  | 123791    | 124928    | ...   |
# | GL456210.1   | ENSEMBL    | exon        | 123791    | 123905    | ...   |
# | GL456210.1   | ENSEMBL    | CDS         | 123791    | 123905    | ...   |
# | ...          | ...        | ...         | ...       | ...       | ...   |
# | chrY         | ENSEMBL    | CDS         | 90838871  | 90839177  | ...   |
# | chrY         | ENSEMBL    | start_codon | 90839174  | 90839177  | ...   |
# | chrY         | ENSEMBL    | stop_codon  | 90838868  | 90838871  | ...   |
# | chrY         | ENSEMBL    | UTR         | 90838868  | 90838871  | ...   |
# +--------------+------------+-------------+-----------+-----------+-------+
# Stranded PyRanges object has 1,617,655 rows and 26 columns from 45 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 21 hidden columns: Score, Strand, Frame, gene_id, gene_type, gene_status, gene_name, ... (+ 14 more.)

# %% [markdown]
# Description of the Narrowpeak format: https://macs3-project.github.io/MACS/docs/narrowPeak.html

# %%
# Function for reading narrowpeak files

def load_narrowpeak(filepath):
    """
    Loads a narrowPeak file into a PyRanges object.
    narrowPeak format is fixed: standard BED 6 columns + 4 signal columns.
    """
    columns = [
        "Chromosome", "Start", "End", "Name", "Score", "Strand",
        "SignalValue", "pValue", "qValue", "Peak"
    ]
    df = pandas.read_csv(filepath, sep=r'\s+', header=None, names=columns)
    return pyranges.PyRanges(df)

# %%
# Read narrowpeak files

chipseq_directory = "ChIP Sequencing Data/"
klf4_control_path = chipseq_directory+"KLF4_BFP_merged_peaks.narrowPeak"
klf4_hic2_path = chipseq_directory+"KLF4_Hic2_merged_peaks.narrowPeak"
hic2_path = chipseq_directory+"Ty1_CTer_Hic2_DSG_MKOS48h_peaks.narrowPeak"

klf4_control_peaks = load_narrowpeak(klf4_control_path)
klf4_hic2_peaks = load_narrowpeak(klf4_hic2_path)
hic2_peaks = load_narrowpeak(hic2_path)

# %%
# Closest gene method using middle of peak

def closest_gene(peaks, annotation, max_distance=1000000, use_center=True, nb_cpu=1):
    # Filter for protein-coding genes
    genes = annotation[annotation.Feature == "gene"]
    genes_df = genes.as_df()

    # Define the transcription start site based on the strand direction
    positive_strand = genes_df["Strand"] == "+"
    negative_strand = genes_df["Strand"] == "-"
    genes_df.loc[positive_strand, "End"] = genes_df.loc[positive_strand, "Start"]
    genes_df.loc[negative_strand, "Start"] = genes_df.loc[negative_strand, "End"]
    tss_positions = pyranges.PyRanges(genes_df)

    # Find the center of each peak
    peak_center = (peaks.df["Start"] + peaks.df["End"]) / 2.0
    if use_center:
        peaks_df = peaks.as_df()
        peaks_df["Start"] = peak_center
        peaks_df["End"] = peak_center
        peaks = pyranges.PyRanges(peaks_df)

    # Find the closest TSS to each peak
    closest_tss = peaks.nearest(tss_positions, nb_cpu=nb_cpu)

    # Filter distances that are too large
    filtered_indices = (closest_tss.df["Distance"] < max_distance).to_list()
    closest_tss_df = closest_tss.as_df()[filtered_indices]
    peak_center = peak_center[filtered_indices]

    # Check if peak is upstream or downstream
    # If the peak center is exactly at the TSS, the gene will be considered upstream
    is_positive = closest_tss_df["Strand_b"] == "+"
    is_negative = closest_tss_df["Strand_b"] == "-"
    tss_position = closest_tss_df["Start_b"]
    closest_tss_df["Upstream"] = False
    closest_tss_df["Downstream"] = False
    # Upstream peaks
    closest_tss_df.loc[is_positive & (peak_center <= tss_position), "Upstream"] = True
    closest_tss_df.loc[is_negative & (peak_center >= tss_position), "Upstream"] = True
    # Downstream peaks
    closest_tss_df.loc[is_negative & (peak_center < tss_position), "Downstream"] = True
    closest_tss_df.loc[is_positive & (peak_center > tss_position), "Downstream"] = True

    # Get up- and downstream distribution
    upstream_indices = closest_tss_df["Upstream"]
    downstream_indices = closest_tss_df["Downstream"]
    upstream_distribution = closest_tss_df[upstream_indices]["Distance"].to_numpy()
    upstream_distribution.sort()
    downstream_distribution = closest_tss_df[downstream_indices]["Distance"].to_numpy()
    downstream_distribution.sort()

    # Score each peak based on distance distribution
    distances = closest_tss_df["Distance"]
    peak_scores = numpy.zeros_like(distances, dtype=float)
    peak_scores[upstream_indices] = [-numpy.log10((numpy.argmax(upstream_distribution == distance)+1)/len(upstream_distribution)) for distance in distances[upstream_indices]]
    peak_scores[downstream_indices] = [-numpy.log10((numpy.argmax(downstream_distribution == distance)+1)/len(downstream_distribution)) for distance in distances[downstream_indices]]
    closest_tss_df["Peak_score"] = peak_scores

    # Score each gene
    gene_scores = closest_tss_df.groupby("gene_name")["Peak_score"].sum().reset_index()
    gene_scores.index = gene_scores["gene_name"]
    gene_scores = gene_scores.drop(columns="gene_name")
    gene_scores = gene_scores.rename(columns={"Peak_score": "chip_score"})

    # Give genes without peaks a score of 0
    all_genes = genes_df["gene_name"].unique()
    gene_scores = gene_scores.reindex(all_genes, fill_value=0.0)
    gene_scores = gene_scores.sort_values("chip_score", ascending=False)

    return gene_scores

# %%
hic2_target_scores = closest_gene(hic2_peaks, annotation, use_center=True, max_distance=1000000)

# %%
hic2_target_scores.query("chip_score>0 and chip_score < 5").plot.density(bw_method=0.05)
cutoff=0.75
axis = pyplot.gca()
axis.axvline(cutoff, linestyle="dashed", color="black")
pyplot.show()

# %% [markdown]
# There are two peaks, where the second likely corresponds to true targets. A cutoff at 0.75 was chosen since this is just before the peak, meaning most true positives are found while minimizing unnecessary false positives.

# %%
hic2_targets = hic2_target_scores.query("chip_score > @cutoff").index.to_list()
print(f"Found {len(hic2_targets)} Hic2 targets")
# Out:
# Found 11405 Hic2 targets

# %%
# Find Klf4 targets with and without Hic2 overexpression

klf4_hic2_target_scores = closest_gene(klf4_hic2_peaks, annotation, use_center=True, max_distance=1000000)
klf4_hic2_target_scores.query("chip_score > 0 and chip_score < 5").plot.density(bw_method=0.05)
cutoff=0.7
axis = pyplot.gca()
axis.axvline(cutoff, linestyle="dashed", color="black")
pyplot.show()
klf4_hic2_targets = klf4_hic2_target_scores.query("chip_score > @cutoff").index.to_list()
print(f"Found {len(klf4_hic2_targets)} targets for Klf4 with Hic2 overexpression")

klf4_control_target_scores = closest_gene(klf4_control_peaks, annotation, use_center=True, max_distance=1000000)
klf4_control_target_scores.query("chip_score > 0 and chip_score < 5").plot.density(bw_method=0.05)
cutoff=0.7
axis = pyplot.gca()
axis.axvline(cutoff, linestyle="dashed", color="black")
pyplot.show()
klf4_control_targets = klf4_control_target_scores.query("chip_score > @cutoff").index.to_list()
print(f"Found {len(klf4_control_targets)} targets for Klf4 without Hic2 overexpression")
# Out:
# Found 11745 targets for Klf4 with Hic2 overexpression
# Found 11532 targets for Klf4 without Hic2 overexpression

# %% [markdown]
# A cutoff of 0.7 is just before the second peak for both Klf4 experiments.

# %%
# Find overlapping binding sites
klf4_targets = numpy.intersect1d(klf4_hic2_targets, klf4_control_targets)
print(f"Found {len(klf4_targets)} overlapping Klf4 targets")

# Shared targets for Hic2 and Klf4
shared_targets = numpy.intersect1d(hic2_targets, klf4_hic2_targets)
print(f"Found {len(shared_targets)} shared targets")
# Out:
# Found 10118 overlapping Klf4 targets
# Found 8444 shared targets

# %%
# Save targets to disk

base_name = "ChIP Sequencing Data/chipseq_targets"

hic2_target_scores.to_csv(f"{base_name}_hic2_scores.csv")
klf4_hic2_target_scores.to_csv(f"{base_name}_klf4_hic2_scores.csv")
klf4_control_target_scores.to_csv(f"{base_name}_klf4_control_scores.csv")

numpy.savetxt(f"{base_name}_hic2_targets.txt", hic2_targets, fmt="%s")
numpy.savetxt(f"{base_name}_klf4_hic2_targets.txt", klf4_hic2_targets, fmt="%s")
numpy.savetxt(f"{base_name}_klf4_control_targets.txt", klf4_control_targets, fmt="%s")

# %% [markdown]
# # Comparison to Cellrank data

# %%
# Compare to cellrank data

# Read saved objects from Cellrank analysis
working_directory = "RNA Sequencing Data/"
base_name = "cellrank_version_5"
adata = scanpy.read_h5ad(
    working_directory+f"/{base_name}_anndata.h5ad"
)
driver_df = pandas.read_csv(
    working_directory+f"{base_name}_driver_genes.csv",
    index_col=0
)

# %%
variable_genes = adata.var_names.to_numpy()
stem_cell_drivers = driver_df.sort_values("Day 12 Control_corr", ascending=True).head(200).index.to_numpy()
dead_end_drivers = driver_df.sort_values("Day 12 Control_corr", ascending=False).head(200).index.to_numpy()

# %%
driver_df.sort_values("Day 12 Control_corr", ascending=False).head(100)
# Out:
#             Day 12 Control_corr  Day 12 Control_pval  Day 12 Control_qval  \
# gene_names
# Cd24a                  0.666144         0.000000e+00         0.000000e+00
# Lmo1                   0.591418         0.000000e+00         0.000000e+00
# Crip2                  0.579628         0.000000e+00         0.000000e+00
# Ctsz                   0.574877         0.000000e+00         0.000000e+00
# Lgals7                 0.573645         0.000000e+00         0.000000e+00
# ...                         ...                  ...                  ...
# Myc                    0.348143        3.048684e-276        3.044111e-275
# Map1b                  0.347409        5.531969e-275        5.468981e-274
# Ggh                    0.346230        5.711266e-273        5.563609e-272
# Tmem147                0.346133        8.344404e-273        8.050133e-272
# Tob1                   0.345044        5.920618e-271        5.630226e-270
#
#             Day 12 Control_ci_low  Day 12 Control_ci_high  mESC_corr  \
# gene_names
# Cd24a                    0.654841                0.677150  -0.666161
# Lmo1                     0.578225                0.604301  -0.591417
# Crip2                    0.566159                0.592789  -0.579637
# Ctsz                     0.561298                0.588148  -0.574908
# Lgals7                   0.560036                0.586943  -0.573641
# ...                           ...                     ...        ...
# Myc                      0.330400                0.365640  -0.348143
# Map1b                    0.329656                0.364916  -0.347409
# Ggh                      0.328460                0.363754  -0.346251
# Tmem147                  0.328362                0.363659  -0.346138
# Tob1                     0.327259                0.362585  -0.345042
#
#                 mESC_pval      mESC_qval  mESC_ci_low  mESC_ci_high
# gene_names
# Cd24a        0.000000e+00   0.000000e+00    -0.677166     -0.654858
# Lmo1         0.000000e+00   0.000000e+00    -0.604301     -0.578224
# Crip2        0.000000e+00   0.000000e+00    -0.592798     -0.566168
# Ctsz         0.000000e+00   0.000000e+00    -0.588177     -0.561329
# Lgals7       0.000000e+00   0.000000e+00    -0.586940     -0.560033
# ...                   ...            ...          ...           ...
# Myc         3.053154e-276  3.048575e-275    -0.365640     -0.330400
# Map1b       5.532772e-275  5.469775e-274    -0.364916     -0.329656
# Ggh         5.259579e-273  5.123600e-272    -0.363774     -0.328482
# Tmem147     8.197085e-273  7.908009e-272    -0.363663     -0.328367
# Tob1        5.957266e-271  5.665076e-270    -0.362583     -0.327257
#
# [100 rows x 10 columns]

# %%
# Find which driver genes are targets for Hic2

hic2_stem_cell_drivers = numpy.intersect1d(stem_cell_drivers, hic2_targets)
hic2_dead_end_drivers = numpy.intersect1d(dead_end_drivers, hic2_targets)

# %%
hic2_stem_cell_drivers
# Out:
# array(['1500009L16Rik', '1700007K13Rik', '2810474O19Rik', 'Agtrap',
#        'Anxa2', 'Anxa3', 'Aox3', 'Arhgap8', 'Arrdc4', 'Atp1b1', 'Blvrb',
#        'Calcoco2', 'Car2', 'Cbx7', 'Ccnb2', 'Ccne1', 'Ccnf', 'Cenpm',
#        'Cited2', 'Col18a1', 'Cox6b2', 'Cox7a1', 'Csrp2', 'Ctgf', 'Cxxc5',
#        'Dhx16', 'Dnmt3b', 'Enah', 'Epha4', 'Fam208a', 'Fgf4', 'Fgfbp1',
#        'Fn1', 'Fxyd6', 'G3bp2', 'Gadd45b', 'Glipr2', 'Gpx4', 'Hip1',
#        'Hmgn2', 'Hspb1', 'Ifitm1', 'Jam2', 'Jarid2', 'Klf2', 'Klk8',
#        'L1td1', 'Lmnb1', 'Ly6e', 'Map1lc3a', 'Marcksl1', 'Mdk', 'Mme',
#        'Msh6', 'Mtf2', 'Mycn', 'Mylpf', 'Nid1', 'Nodal', 'Phc1', 'Phyh',
#        'Pigp', 'Psme1', 'Psme2', 'Ptma', 'Rbpms2', 'Rest', 'Rif1',
#        'Rnf31', 'Sall1', 'Sfrp1', 'Sh3bgrl3', 'Slc25a20', 'Slc2a1',
#        'Slc2a3', 'Sparc', 'St8sia1', 'Syce2', 'Tcea3', 'Tcf7l1', 'Tcf7l2',
#        'Tfcp2l1', 'Tle4', 'Tmem40', 'Tmsb10', 'Trim71', 'Tsc22d1',
#        'Txnip', 'Ucp2', 'Upp1', 'Wbscr27', 'Wfdc2', 'Zfp42', 'Zfp462'],
#       dtype=object)

# %%
hic2_dead_end_drivers
# Out:
# array(['9530059O14Rik', 'Abhd16a', 'Ablim1', 'Aldh3a1', 'Alox12b', 'Amn',
#        'Ankrd12', 'Ankrd13b', 'Anxa5', 'Anxa8', 'Ap1m2', 'Aqp3', 'Avil',
#        'B2m', 'Barx2', 'Birc7', 'Bspry', 'Card19', 'Cbr3', 'Ccdc109b',
#        'Ccl7', 'Ccnd1', 'Ccnd2', 'Cd24a', 'Cd44', 'Cdh1', 'Cdkn1a',
#        'Cgref1', 'Cisd3', 'Cltb', 'Crabp2', 'Crip2', 'Ctsb', 'Ctsc',
#        'Ctsz', 'Ddah2', 'Dgat2', 'Dhrs3', 'Dkkl1', 'Dlgap1', 'Dmrtc2',
#        'Dnah17', 'Dpysl3', 'Dqx1', 'Dsp', 'Efna3', 'Emb', 'Emp2', 'Emp3',
#        'Esd', 'Fabp5', 'Fads3', 'Fam134b', 'Fam195a', 'Fam213a', 'Fam83g',
#        'Fbln2', 'Fbp2', 'Fetub', 'Fgf18', 'Fkbp11', 'Gatm', 'Gch1', 'Ggh',
#        'Gpm6b', 'Gprc5a', 'Gsto1', 'Hmgb3', 'Hmha1', 'Hoxa7', 'Ifi30',
#        'Ifrd1', 'Isyna1', 'Itgb4', 'Kcnn4', 'Klk10', 'Klk14', 'Krt13',
#        'Krt16', 'Krt8', 'Lad1', 'Lgals7', 'Lmna', 'Lmo1', 'Ltbp1',
#        'Ly6g6c', 'Mal', 'Mal2', 'Map1b', 'Marc2', 'Mgst3', 'Miat', 'Misp',
#        'Mt1', 'Mt2', 'Myc', 'Myl7', 'Ndrg1', 'Nectin4', 'Nkd2', 'Npr3',
#        'Nradd', 'Nrip3', 'Nupr1', 'Ovol1', 'P3h4', 'Pcolce', 'Pcolce2',
#        'Pdgfa', 'Perp', 'Pga5', 'Phlda3', 'Phox2a', 'Pkp1', 'Pla2g12a',
#        'Plec', 'Plek2', 'Pmepa1', 'Ppa1', 'Prkaa2', 'Prr13', 'Psmb10',
#        'Ptprv', 'Rac3', 'Rassf1', 'Rtkn', 'Rtn4r', 'S100a14', 'S100a16',
#        'Sat1', 'Scrn1', 'Sdcbp2', 'Serpinb1a', 'Serpinb6c', 'Shisa8',
#        'Shtn1', 'Slc36a3os', 'Slurp1', 'Smagp', 'Smpdl3a', 'Spink2',
#        'Spint2', 'St14', 'Taok3', 'Tgm2', 'Them5', 'Tlx2', 'Tmbim1',
#        'Tmem238', 'Tmem43', 'Tnfrsf13c', 'Tns1', 'Tob1', 'Tppp3',
#        'Trim47', 'Trpv3', 'Tshz1', 'Tubb3', 'Txn1', 'Urah', 'Zbtb7c',
#        'Zfas1'], dtype=object)

# %%
# Overlapping Klf4 targets
klf4_stem_cell_drivers = numpy.intersect1d(stem_cell_drivers, klf4_targets)
klf4_dead_end_drivers = numpy.intersect1d(dead_end_drivers, klf4_targets)

# %%
klf4_stem_cell_drivers
# Out:
# array(['1500009L16Rik', '2810474O19Rik', 'Agtrap', 'Aire', 'Anxa3',
#        'Aox3', 'Arhgap8', 'Arl6ip1', 'Arrdc4', 'Atp1b1', 'Blvrb', 'Bnip3',
#        'Calcoco2', 'Car2', 'Ccnb2', 'Ccne1', 'Ccnf', 'Cd59a', 'Cdo1',
#        'Cenpm', 'Cited2', 'Cotl1', 'Cox7a1', 'Csrp2', 'Ctgf', 'Cxxc5',
#        'Dlc1', 'Dnmt3b', 'Enah', 'Epha4', 'Erdr1', 'Fam208a', 'Fn1',
#        'Fxyd6', 'G3bp2', 'Gadd45b', 'Glipr2', 'Gpx4', 'H2afv', 'Hip1',
#        'Hmgb2', 'Hspb1', 'Jam2', 'Jarid2', 'Kdm3a', 'Klf2', 'Klhl13',
#        'L1td1', 'Lmnb1', 'Lrpap1', 'Ly6e', 'Map1lc3a', 'Msh6', 'Mtf2',
#        'Mycn', 'Nedd4', 'Nid1', 'Nodal', 'Phc1', 'Phyh', 'Pigp', 'Psme2',
#        'Ptma', 'Rbpms2', 'Rdm1', 'Rest', 'Rif1', 'Rnf31', 'Sall1',
#        'Sh3bgrl3', 'Sin3b', 'Slc25a20', 'Slc2a1', 'Slc2a3', 'Snhg11',
#        'Suz12', 'Syce2', 'Tcea3', 'Tcf7l1', 'Tcf7l2', 'Tdgf1', 'Tfcp2l1',
#        'Tle4', 'Tmsb10', 'Trim71', 'Tsc22d1', 'Ucp2', 'Zfp42', 'Zfp462'],
#       dtype=object)

# %%
klf4_dead_end_drivers
# Out:
# array(['9530059O14Rik', 'Abhd16a', 'Ablim1', 'Aldh3a1', 'Alox12b', 'Amn',
#        'Ankrd12', 'Ankrd13b', 'Anxa5', 'Anxa8', 'Ap1m2', 'Aqp3', 'Barx2',
#        'Bspry', 'Card19', 'Cbr3', 'Ccdc109b', 'Ccl7', 'Ccnd1', 'Ccnd2',
#        'Cd24a', 'Cd44', 'Cdkn1a', 'Cgref1', 'Chst13', 'Cisd3', 'Cltb',
#        'Crabp2', 'Crip2', 'Ctsb', 'Ctsc', 'Ctsz', 'Ddah2', 'Dgat2',
#        'Dhrs3', 'Dkkl1', 'Dlgap1', 'Dsp', 'Efna3', 'Emb', 'Emp2', 'Emp3',
#        'Esd', 'Fabp5', 'Fads3', 'Fam134b', 'Fam195a', 'Fam83g', 'Fbln2',
#        'Fbp2', 'Fetub', 'Fgf18', 'Gatm', 'Gch1', 'Ggh', 'Gprc5a', 'Gsto1',
#        'H2-D1', 'Hmha1', 'Homer2', 'Hoxa7', 'Ifi30', 'Isyna1', 'Itgb4',
#        'Kcnn4', 'Kiss1r', 'Klk10', 'Klk14', 'Krt13', 'Krt14', 'Krt16',
#        'Krt8', 'Lad1', 'Lgals7', 'Lmna', 'Lmo1', 'Ltbp1', 'Ly6g6c', 'Mal',
#        'Marc2', 'Mgst3', 'Miat', 'Misp', 'Mt1', 'Mt2', 'Myc', 'Myl7',
#        'Ndrg1', 'Nectin4', 'Nkd2', 'Npr3', 'Nradd', 'Nupr1', 'Obsl1',
#        'Ovol1', 'P3h4', 'Pcolce', 'Pcolce2', 'Pdgfa', 'Perp', 'Phlda3',
#        'Phox2a', 'Pkp1', 'Plec', 'Plek2', 'Pmepa1', 'Ppa1', 'Prkaa2',
#        'Prr13', 'Ptprv', 'Rac3', 'Rassf1', 'Rtkn', 'Rtn4r', 'S100a1',
#        'S100a14', 'S100a16', 'Sat1', 'Scrn1', 'Serpinb1a', 'Shisa8',
#        'Shtn1', 'Slc36a3os', 'Slurp1', 'Smagp', 'Smpdl3a', 'Snhg12',
#        'Spink2', 'Spint1', 'Spint2', 'St14', 'Taok3', 'Tgm2', 'Them5',
#        'Tlx2', 'Tmbim1', 'Tmem43', 'Tnfrsf13c', 'Tns1', 'Tob1', 'Tppp3',
#        'Trim47', 'Trpv3', 'Tshz1', 'Tubb3', 'Txn1', 'Urah', 'Zbtb7c',
#        'Zfas1'], dtype=object)

# %%
# Shared stem cell drivers
shared_stem_cell_drivers = numpy.intersect1d(hic2_stem_cell_drivers, klf4_stem_cell_drivers)
shared_stem_cell_drivers
# Out:
# array(['1500009L16Rik', '2810474O19Rik', 'Agtrap', 'Anxa3', 'Aox3',
#        'Arhgap8', 'Arrdc4', 'Atp1b1', 'Blvrb', 'Calcoco2', 'Car2',
#        'Ccnb2', 'Ccne1', 'Ccnf', 'Cenpm', 'Cited2', 'Cox7a1', 'Csrp2',
#        'Ctgf', 'Cxxc5', 'Dnmt3b', 'Enah', 'Epha4', 'Fam208a', 'Fn1',
#        'Fxyd6', 'G3bp2', 'Gadd45b', 'Glipr2', 'Gpx4', 'Hip1', 'Hspb1',
#        'Jam2', 'Jarid2', 'Klf2', 'L1td1', 'Lmnb1', 'Ly6e', 'Map1lc3a',
#        'Msh6', 'Mtf2', 'Mycn', 'Nid1', 'Nodal', 'Phc1', 'Phyh', 'Pigp',
#        'Psme2', 'Ptma', 'Rbpms2', 'Rest', 'Rif1', 'Rnf31', 'Sall1',
#        'Sh3bgrl3', 'Slc25a20', 'Slc2a1', 'Slc2a3', 'Syce2', 'Tcea3',
#        'Tcf7l1', 'Tcf7l2', 'Tfcp2l1', 'Tle4', 'Tmsb10', 'Trim71',
#        'Tsc22d1', 'Ucp2', 'Zfp42', 'Zfp462'], dtype=object)

# %%
# Shared dead end drivers
shared_dead_end_drivers = numpy.intersect1d(hic2_dead_end_drivers, klf4_dead_end_drivers)
shared_dead_end_drivers
# Out:
# array(['9530059O14Rik', 'Abhd16a', 'Ablim1', 'Aldh3a1', 'Alox12b', 'Amn',
#        'Ankrd12', 'Ankrd13b', 'Anxa5', 'Anxa8', 'Ap1m2', 'Aqp3', 'Barx2',
#        'Bspry', 'Card19', 'Cbr3', 'Ccdc109b', 'Ccl7', 'Ccnd1', 'Ccnd2',
#        'Cd24a', 'Cd44', 'Cdkn1a', 'Cgref1', 'Cisd3', 'Cltb', 'Crabp2',
#        'Crip2', 'Ctsb', 'Ctsc', 'Ctsz', 'Ddah2', 'Dgat2', 'Dhrs3',
#        'Dkkl1', 'Dlgap1', 'Dsp', 'Efna3', 'Emb', 'Emp2', 'Emp3', 'Esd',
#        'Fabp5', 'Fads3', 'Fam134b', 'Fam195a', 'Fam83g', 'Fbln2', 'Fbp2',
#        'Fetub', 'Fgf18', 'Gatm', 'Gch1', 'Ggh', 'Gprc5a', 'Gsto1',
#        'Hmha1', 'Hoxa7', 'Ifi30', 'Isyna1', 'Itgb4', 'Kcnn4', 'Klk10',
#        'Klk14', 'Krt13', 'Krt16', 'Krt8', 'Lad1', 'Lgals7', 'Lmna',
#        'Lmo1', 'Ltbp1', 'Ly6g6c', 'Mal', 'Marc2', 'Mgst3', 'Miat', 'Misp',
#        'Mt1', 'Mt2', 'Myc', 'Myl7', 'Ndrg1', 'Nectin4', 'Nkd2', 'Npr3',
#        'Nradd', 'Nupr1', 'Ovol1', 'P3h4', 'Pcolce', 'Pcolce2', 'Pdgfa',
#        'Perp', 'Phlda3', 'Phox2a', 'Pkp1', 'Plec', 'Plek2', 'Pmepa1',
#        'Ppa1', 'Prkaa2', 'Prr13', 'Ptprv', 'Rac3', 'Rassf1', 'Rtkn',
#        'Rtn4r', 'S100a14', 'S100a16', 'Sat1', 'Scrn1', 'Serpinb1a',
#        'Shisa8', 'Shtn1', 'Slc36a3os', 'Slurp1', 'Smagp', 'Smpdl3a',
#        'Spink2', 'Spint2', 'St14', 'Taok3', 'Tgm2', 'Them5', 'Tlx2',
#        'Tmbim1', 'Tmem43', 'Tnfrsf13c', 'Tns1', 'Tob1', 'Tppp3', 'Trim47',
#        'Trpv3', 'Tshz1', 'Tubb3', 'Txn1', 'Urah', 'Zbtb7c', 'Zfas1'],
#       dtype=object)

# %% [markdown]
# The most interesting shared targets among the dead end drivers are:
# - Genes involved in epithelial cell differentiation: KRT17;KRT16;KRT13;OVOL1;CTSB
# - Genes involved in epidermal development: CRABP2;FABP5;KLK14;OVOL1
#
# Especially Ovol1 and the keratin genes are relevant. Ovol1 promotes mesenchymal-to-epithelial transition
#
# The most interesting stem cell drivers are:
# - Genes regulating epithelial to mesenchymal transition: EPHA4;TCF7L2;SFRP1;MDK;GLIPR2
#
# Mdk is especially interesting as a driver of EMT with interesting expression trends.

# %% [markdown]
# # GO analysis

# %% [markdown]
# ## GO biological process

# %%
# Enriched terms among the dead-end drivers

enr = gseapy.enrichr(
    gene_list=list(shared_dead_end_drivers),
    gene_sets='GO_Biological_Process_2025',
    organism='mouse',
    outdir=None
)
enr.res2d.sort_values('Adjusted P-value').head(20)
# Out:
#                       Gene_set  \
# 0   GO_Biological_Process_2025
# 1   GO_Biological_Process_2025
# 2   GO_Biological_Process_2025
# 3   GO_Biological_Process_2025
# 4   GO_Biological_Process_2025
# 5   GO_Biological_Process_2025
# 6   GO_Biological_Process_2025
# 7   GO_Biological_Process_2025
# 8   GO_Biological_Process_2025
# 9   GO_Biological_Process_2025
# 10  GO_Biological_Process_2025
# 11  GO_Biological_Process_2025
# 12  GO_Biological_Process_2025
# 13  GO_Biological_Process_2025
# 14  GO_Biological_Process_2025
# 15  GO_Biological_Process_2025
# 16  GO_Biological_Process_2025
# 17  GO_Biological_Process_2025
# 18  GO_Biological_Process_2025
# 19  GO_Biological_Process_2025
#
#                                                  Term Overlap   P-value  \
# 0                          Bleb Assembly (GO:0032060)     2/6  0.000716
# 1   Regulation of Keratinocyte Differentiation (GO...    3/30  0.001187
# 2                       Skin Development (GO:0043588)    4/69  0.001398
# 3          Collagen Biosynthetic Process (GO:0032964)     2/9  0.001696
# 4   Positive Regulation of Mesenchymal Cell Prolif...     2/9  0.001696
# 5           Cellular Response to Hypoxia (GO:0071456)    4/77  0.002096
# 6   Cellular Response to Decreased Oxygen Levels (...    4/78  0.002197
# 7   Negative Regulation of Epithelial Cell Apoptot...    2/11  0.002567
# 8   Regulation of Mesenchymal Cell Proliferation (...    2/11  0.002567
# 9                 Fatty Acid Homeostasis (GO:0055089)    2/11  0.002567
# 10                 Epidermis Development (GO:0008544)    4/86  0.003134
# 11    Monoacylglycerol Metabolic Process (GO:0046462)    2/13  0.003608
# 12       Regulation of Apoptotic Process (GO:0042981)  12/704  0.003967
# 13  Regulation of Monocyte Differentiation (GO:004...    2/15  0.004812
# 14    Positive Regulation of Proteolysis (GO:0045862)    3/52  0.005775
# 15        Epidermal Cell Differentiation (GO:0009913)    3/56  0.007099
# 16         Nuclear Envelope Organization (GO:0006998)    2/19  0.007695
# 17      fatty-acyl-CoA Metabolic Process (GO:0035337)    2/19  0.007695
# 18  Positive Regulation of Granulocyte Chemotaxis ...    2/21  0.009364
# 19         Establishment of Skin Barrier (GO:0061436)    2/21  0.009364
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0           0.213342            0                     0   71.942029
# 1           0.213342            0                     0   16.085158
# 2           0.213342            0                     0    8.957014
# 3           0.213342            0                     0   41.103520
# 4           0.213342            0                     0   41.103520
# 5           0.213342            0                     0    7.972200
# 6           0.213342            0                     0    7.864070
# 7           0.213342            0                     0   31.966184
# 8           0.213342            0                     0   31.966184
# 9           0.213342            0                     0   31.966184
# 10          0.236731            0                     0    7.093974
# 11          0.249829            0                     0   26.151515
# 12          0.253577            0                     0    2.596821
# 13          0.285635            0                     0   22.125975
# 14          0.303098            0                     0    8.853419
# 15          0.303098            0                     0    8.183584
# 16          0.303098            0                     0   16.916454
# 17          0.303098            0                     0   16.916454
# 18          0.303098            0                     0   15.134249
# 19          0.303098            0                     0   15.134249
#
#     Combined Score                                              Genes
# 0       520.947578                                          EMP2;EMP3
# 1       108.358628                                    PKP1;HOXA7;AQP3
# 2        58.873150                             ST14;ITGB4;KRT16;PDGFA
# 3       262.221336                                        P3H4;PCOLCE
# 4       262.221336                                          MYC;PDGFA
# 5        49.170765                                MYC;LMNA;AQP3;NDRG1
# 6        48.132132                                MYC;LMNA;AQP3;NDRG1
# 7       190.675178                                       PRKAA2;NUPR1
# 8       190.675178                                          MYC;PDGFA
# 9       190.675178                                       DGAT2;PRKAA2
# 10       40.900759                           CRABP2;FABP5;KLK14;OVOL1
# 11      147.094423                                      DGAT2;ABHD16A
# 12       14.359814  PRKAA2;CCND2;RTKN;DDAH2;MYC;ANXA5;DKKL1;NUPR1;...
# 13      118.077729                                          MYC;HOXA7
# 14       45.631901                                     PERP;CTSC;NKD2
# 15       40.491185                                   ST14;KRT16;OVOL1
# 16       82.335833                                        TMEM43;LMNA
# 17       82.335833                                        DGAT2;THEM5
# 18       70.690460                                       PERP;S100A14
# 19       70.690460                                      KRT16;ALOX12B

# %% [markdown]
# Keratinocyte differentiation and epidermis development is included.

# %%
# Enriched terms among the stem cell drivers

enr = gseapy.enrichr(
    gene_list=list(shared_stem_cell_drivers),
    gene_sets='GO_Biological_Process_2025',
    organism='mouse',
    outdir=None
)
enr.res2d.sort_values('Adjusted P-value').head(20)
# Out:
#                       Gene_set  \
# 0   GO_Biological_Process_2025
# 1   GO_Biological_Process_2025
# 2   GO_Biological_Process_2025
# 3   GO_Biological_Process_2025
# 4   GO_Biological_Process_2025
# 5   GO_Biological_Process_2025
# 6   GO_Biological_Process_2025
# 7   GO_Biological_Process_2025
# 8   GO_Biological_Process_2025
# 9   GO_Biological_Process_2025
# 10  GO_Biological_Process_2025
# 11  GO_Biological_Process_2025
# 12  GO_Biological_Process_2025
# 13  GO_Biological_Process_2025
# 14  GO_Biological_Process_2025
# 15  GO_Biological_Process_2025
# 16  GO_Biological_Process_2025
# 17  GO_Biological_Process_2025
# 18  GO_Biological_Process_2025
# 19  GO_Biological_Process_2025
#
#                                                  Term Overlap   P-value  \
# 0   G1/S Transition of Mitotic Cell Cycle (GO:0000...    4/64  0.000075
# 1       Cell Cycle G1/S Phase Transition (GO:0044843)    4/66  0.000084
# 2      L-ascorbic Acid Metabolic Process (GO:0019852)     2/5  0.000120
# 3     Maintenance of DNA Repeat Elements (GO:0043570)     2/5  0.000120
# 4       Monosaccharide Metabolic Process (GO:0005996)     2/7  0.000251
# 5   Positive Regulation of Cell Adhesion (GO:0045785)    4/92  0.000305
# 6   Somatic Recombination of Immunoglobulin Gene S...     2/8  0.000334
# 7   Positive Regulation of Neuron Differentiation ...    3/42  0.000427
# 8   Positive Regulation of Intracellular Signal Tr...   9/652  0.000434
# 9     Fatty Acid Transmembrane Transport (GO:1902001)    2/11  0.000651
# 10               Nodal Signaling Pathway (GO:0038092)    2/11  0.000651
# 11   Mitotic Cell Cycle Phase Transition (GO:0044772)   4/113  0.000665
# 12        Dehydroascorbic Acid Transport (GO:0070837)    2/12  0.000779
# 13  Negative Regulation of Transcription by RNA Po...   9/732  0.000991
# 14   Regulation of ERK1 and ERK2 Cascade (GO:0070372)   5/223  0.001107
# 15                      D-glucose Import (GO:0046323)    2/16  0.001404
# 16  Negative Regulation of Gene Expression (GO:001...   6/364  0.001717
# 17  Embryonic Digestive Tract Development (GO:0048...    2/19  0.001987
# 18  Regulation of Neuron Differentiation (GO:0045664)    3/76  0.002404
# 19              Myoblast Differentiation (GO:0045445)    2/21  0.002429
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0           0.019549            0                     0   20.070707
# 1           0.019549            0                     0   19.421310
# 2           0.019549            0                     0  195.362745
# 3           0.019549            0                     0  195.362745
# 4           0.031067            0                     0  117.205882
# 5           0.031067            0                     0   13.665289
# 6           0.031067            0                     0   97.666667
# 7           0.031430            0                     0   22.836969
# 8           0.031430            0                     0    4.425541
# 9           0.036118            0                     0   65.101307
# 10          0.036118            0                     0   65.101307
# 11          0.036118            0                     0   11.020851
# 12          0.039075            0                     0   58.588235
# 13          0.046148            0                     0    3.919529
# 14          0.048115            0                     0    6.955540
# 15          0.057205            0                     0   41.840336
# 16          0.065835            0                     0    5.125349
# 17          0.071970            0                     0   34.451557
# 18          0.075573            0                     0   12.179718
# 19          0.075573            0                     0   30.821981
#
#     Combined Score                                              Genes
# 0       190.736599                            TRIM71;CCNB2;CCNE1;CCNF
# 1       182.219723                            TRIM71;CCNB2;CCNE1;CCNF
# 2      1763.848974                                      SLC2A1;SLC2A3
# 3      1763.848974                                        MSH6;TCF7L2
# 4       971.774573                                      SLC2A1;SLC2A3
# 5       110.631377                            EPHA4;CITED2;NID1;NODAL
# 6       781.895717                                        MSH6;TCF7L1
# 7       177.163617                                 TCF7L2;TCF7L1;REST
# 8        34.266204  RNF31;EPHA4;TCF7L2;HIP1;CITED2;FN1;CXXC5;KLF2;...
# 9       477.675721                                    SLC2A1;SLC25A20
# 10      477.675721                                       CITED2;NODAL
# 11       80.629800                            TRIM71;CCNB2;CCNE1;CCNF
# 12      419.337267                                      SLC2A1;SLC2A3
# 13       27.110944  TLE4;TCF7L2;TCF7L1;REST;SALL1;CITED2;DNMT3B;CX...
# 14       47.340450                     EPHA4;ARHGAP8;GLIPR2;FN1;NODAL
# 15      274.831355                                      SLC2A1;SLC2A3
# 16       32.635343                 TRIM71;EPHA4;REST;MYCN;CITED2;MTF2
# 17      214.329457                                       SALL1;RBPMS2
# 18       73.449779                                 TCF7L2;TCF7L1;REST
# 19      185.556267                                        TCF7L2;REST

# %%
# Prerank analysis on filtered dataframe, dead end drivers

rank_data = driver_df[["Day 12 Control_corr"]].sort_values('Day 12 Control_corr', ascending=False).dropna()
# Filter out genes that are not targets
rank_data = rank_data.query("gene_names in @shared_targets")

# Run GSEA Prerank
pre_res = gseapy.prerank(
    rnk=rank_data, 
    gene_sets="GO_Biological_Process_2025",
    threads=16,
    min_size=5,
    max_size=1000
)
pre_res.res2d.sort_values('NES', ascending=False).head(20)
# Out:
#         Name                                               Term        ES  \
# 5    prerank  Proteolysis Involved in Protein Catabolic Proc...  0.834872
# 8    prerank             Protein Catabolic Process (GO:0030163)  0.706336
# 19   prerank            Peptide Hormone Processing (GO:0016486)  0.759811
# 27   prerank  Positive Regulation of Cell Projection Organiz...  0.691953
# 28   prerank  Positive Regulation of Neuron Projection Devel...  0.734695
# 45   prerank         Collagen Biosynthetic Process (GO:0032964)  0.740486
# 48   prerank      Regulation of Glycolytic Process (GO:0006110)  0.741704
# 49   prerank  Plasma Membrane Bounded Cell Projection Assemb...  0.549998
# 53   prerank     Protein Localization to Organelle (GO:0033365)  0.696768
# 58   prerank  Positive Regulation of Leukocyte Migration (GO...  0.717343
# 61   prerank  Positive Regulation of MAP Kinase Activity (GO...  0.656389
# 65   prerank  Regulation of Lamellipodium Assembly (GO:0010591)  0.705872
# 69   prerank                 Epidermis Development (GO:0008544)  0.543994
# 71   prerank                Granulocyte Chemotaxis (GO:0071621)  0.710041
# 75   prerank                 Calcium Ion Transport (GO:0006816)  0.696783
# 87   prerank  Positive Regulation of Apoptotic Signaling Pat...  0.585549
# 88   prerank                   Negative Chemotaxis (GO:0050919)  0.702035
# 93   prerank    Positive Regulation of Proteolysis (GO:0045862)  0.681053
# 96   prerank       Epithelial Cell Differentiation (GO:0030855)  0.522746
# 104  prerank  Homophilic Cell Adhesion via Plasma Membrane A...  0.615176
#
#           NES NOM p-val FDR q-val FWER p-val Tag %  Gene %  \
# 5     1.67359  0.007449       1.0      0.832   3/6   9.20%
# 8    1.580043  0.038113       1.0      0.987   3/9   9.20%
# 19   1.509478  0.032967       1.0        1.0   1/6   0.44%
# 27   1.463737  0.083026       1.0        1.0   2/7  10.98%
# 28   1.455047  0.063218       1.0        1.0   2/6  10.98%
# 45   1.404136  0.084656       1.0        1.0   2/5  13.53%
# 48   1.399746  0.091575       1.0        1.0   2/5   3.33%
# 49   1.399203  0.092784       1.0        1.0  5/15   8.87%
# 53   1.387863  0.087931       1.0        1.0   2/6   6.87%
# 58      1.372  0.089184       1.0        1.0   3/5  21.73%
# 61   1.362841  0.116697       1.0        1.0   3/7  15.41%
# 65   1.352343  0.124304       1.0        1.0   1/5   5.65%
# 69   1.348221  0.114783       1.0        1.0  8/13  29.05%
# 71   1.342894  0.098743       1.0        1.0   3/5  21.06%
# 75   1.326422  0.152672       1.0        1.0   2/5  15.85%
# 87   1.302396  0.160804       1.0        1.0   5/9  25.61%
# 88    1.30122   0.15971       1.0        1.0   2/5  20.73%
# 93     1.2923  0.165468       1.0        1.0   4/5  18.96%
# 96   1.287628  0.143836       1.0        1.0  6/13  23.95%
# 104  1.271963  0.177122       1.0        1.0   2/7  10.86%
#
#                                            Lead_genes
# 5                                      Ctsz;Ctsb;Ctsc
# 8                                      Ctsz;Ctsb;Ctsc
# 19                                               Ctsz
# 27                                        Avil;Dpysl3
# 28                                        Avil;Dpysl3
# 45                                        Pcolce;P3h4
# 48                                       Nupr1;Prkaa2
# 49                        Emp2;Avil;Shtn1;Emp3;Ablim1
# 53                                        Prkaa2;Lmna
# 58                                    Edn2;Lgals3;Zp3
# 61                                  Taok3;Pdgfa;Fgf18
# 65                                               Avil
# 69   Fabp5;Ovol1;Crabp2;Klk14;Gjb5;Emp1;Krtdap;Ppp3ca
# 71                                   Ccl7;Edn2;Lgals3
# 75                                        Kcnn4;Trpv3
# 87                     Nupr1;Bbc3;App;Tnfrsf12a;Ddit3
# 88                                       Pdgfa;Sema3c
# 93                                 Perp;Ctsc;Nkd2;App
# 96                  Ovol1;Ctsb;Krt13;Krt16;Lgals3;Ehf
# 104                                       Nectin4;Emb

# %%
# Prerank analysis on filtered dataframe, stem cell drivers

rank_data = driver_df[["mESC_corr"]].sort_values("mESC_corr", ascending=False).dropna()
# Filter out genes that are not targets
rank_data = rank_data.query("gene_names in @shared_targets")

# Run GSEA Prerank
pre_res = gseapy.prerank(
    rnk=rank_data, 
    gene_sets="GO_Biological_Process_2025",
    threads=16,
    min_size=5,
    max_size=1000
)
pre_res.res2d.sort_values('NES', ascending=False).head(20)
# Out:
#        Name                                               Term        ES  \
# 0   prerank   Protein-Containing Complex Assembly (GO:0065003)  0.657207
# 1   prerank                Chromatin Organization (GO:0006325)  0.695731
# 2   prerank                  Chromatin Remodeling (GO:0006338)  0.714368
# 3   prerank       Regulation of Insulin Secretion (GO:0050796)  0.907527
# 4   prerank            Protein Polyubiquitination (GO:0000209)  0.744508
# 6   prerank  Regulation of Epithelial to Mesenchymal Transi...  0.576838
# 7   prerank  Negative Regulation of Protein Phosphorylation...  0.851712
# 8   prerank  Positive Regulation of DNA-binding Transcripti...  0.662308
# 10  prerank            Nervous System Development (GO:0007399)  0.464745
# 11  prerank  Host-Mediated Suppression of Symbiont Invasion...  0.795419
# 12  prerank             Stem Cell Differentiation (GO:0048863)  0.757071
# 13  prerank  Positive Regulation of Cell Cycle Process (GO:...  0.723552
# 14  prerank  Negative Regulation of DNA-templated Transcrip...   0.39196
# 15  prerank  Negative Regulation of Epithelial to Mesenchym...  0.785986
# 16  prerank       Canonical Wnt Signaling Pathway (GO:0060070)  0.719394
# 17  prerank  Negative Regulation of Transcription by RNA Po...  0.402797
# 18  prerank  Negative Regulation of Protein Secretion (GO:0...  0.789704
# 19  prerank    Central Nervous System Development (GO:0007417)  0.547318
# 21  prerank  Cellular Response to Transforming Growth Facto...   0.52285
# 23  prerank  Negative Regulation of miRNA Transcription (GO...  0.769423
#
#          NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# 0   1.875214       0.0  0.296917      0.158  10/18  23.17%
# 1   1.802714       0.0  0.425162      0.368   7/13  10.98%
# 2   1.759025  0.004474   0.52367      0.555   6/11  10.98%
# 3   1.750743       0.0  0.443981      0.594    3/5   7.98%
# 4   1.711937  0.004425  0.567348      0.752    3/8   7.87%
# 6   1.656541  0.014085  0.875881      0.921  11/19  31.82%
# 7    1.62291  0.007937       1.0      0.968    2/5   7.43%
# 8   1.608613  0.028369       1.0      0.977   4/10   7.87%
# 10  1.599878  0.002551       1.0      0.981  12/38  18.74%
# 11  1.576399  0.018672       1.0      0.996    3/5  10.42%
# 12  1.576255   0.02439       1.0      0.996    3/6   7.43%
# 13   1.56816  0.034934       1.0      0.996    6/7  25.06%
# 14   1.53729       0.0       1.0      0.999  21/80  15.85%
# 15  1.536099  0.039735       1.0      0.999    4/5  19.62%
# 16  1.532347   0.04086       1.0      0.999    4/7  15.85%
# 17  1.532048   0.01084       1.0      0.999  17/62  15.85%
# 18  1.526605  0.028513       1.0      0.999    3/5  12.31%
# 19  1.526416   0.02934  0.979732      0.999   6/17  16.41%
# 21  1.475335   0.06089       1.0        1.0   7/18  21.51%
# 23  1.463999  0.071429       1.0        1.0    1/5   2.88%
#
#                                            Lead_genes
# 0   Gpx4;Fn1;Slc2a1;Hip1;Tcf7l2;Nrxn1;Lamc1;Mapt;F...
# 1           Hmgn2;Jarid2;Phc1;Tcf7l1;Rest;Kdm5b;Cecr2
# 2                   Jarid2;Phc1;Mtf2;Rest;Kdm5b;Cecr2
# 3                                   Rest;Sfrp1;Tcf7l2
# 4                                 Arrdc4;Trim71;Rnf31
# 6   Glipr2;Sfrp1;Tcf7l2;Epha4;Smad7;Spry2;Fermt2;R...
# 7                                         Hspb1;Sfrp1
# 8                            Tcf7l1;Nodal;Anxa3;Rnf31
# 10  Jarid2;Fn1;Trim71;Slc2a1;Marcks;Nrxn1;Adam23;N...
# 11                                 Ifitm1;Ly6e;Ifitm3
# 12                                  Jarid2;Mtf2;Sfrp1
# 13              Nusap1;Aurkb;Incenp;Kif20b;Rgcc;Birc5
# 14  Phc1;Tcf7l1;Rest;Dnmt3b;Klf2;Cited2;Cxxc5;Sall...
# 15                            Sfrp1;Epha4;Smad7;Spry2
# 16                          Tcf7l1;Sfrp1;Tcf7l2;Smad7
# 17  Tcf7l1;Rest;Dnmt3b;Klf2;Cited2;Cxxc5;Sall1;Tcf...
# 18                               Rest;Sfrp1;Rab11fip1
# 19              Jarid2;Slc2a1;Ptch1;Marcks;Adam23;Sct
# 21        Sfrp1;Usp9x;Lefty1;Fos;Smad7;Zfp36l1;Fermt2
# 23                                               Rest

# %% [markdown]
# ## MSigDB Hallmark

# %%
# Enriched terms among the dead-end drivers

enr = gseapy.enrichr(
    gene_list=list(shared_dead_end_drivers),
    gene_sets='MSigDB_Hallmark_2020',
    organism='mouse',
    outdir=None
)
enr.res2d.sort_values('Adjusted P-value').head(20)
# Out:
#                 Gene_set                               Term Overlap  \
# 0   MSigDB_Hallmark_2020            Estrogen Response Early  12/200
# 1   MSigDB_Hallmark_2020                        p53 Pathway  12/200
# 2   MSigDB_Hallmark_2020               IL-2/STAT5 Signaling  10/199
# 3   MSigDB_Hallmark_2020             Estrogen Response Late   9/200
# 4   MSigDB_Hallmark_2020  Epithelial Mesenchymal Transition   8/200
# 5   MSigDB_Hallmark_2020                          Apoptosis   7/161
# 6   MSigDB_Hallmark_2020      TNF-alpha Signaling via NF-kB   7/200
# 7   MSigDB_Hallmark_2020                  Androgen Response   5/100
# 8   MSigDB_Hallmark_2020              Xenobiotic Metabolism   6/200
# 9   MSigDB_Hallmark_2020                     UV Response Up   5/158
# 10  MSigDB_Hallmark_2020                            Hypoxia   5/200
# 11  MSigDB_Hallmark_2020                   mTORC1 Signaling   5/200
# 12  MSigDB_Hallmark_2020              Inflammatory Response   5/200
# 13  MSigDB_Hallmark_2020                       Angiogenesis    2/36
# 14  MSigDB_Hallmark_2020         Wnt-beta Catenin Signaling    2/42
# 15  MSigDB_Hallmark_2020                         Myogenesis   4/200
# 16  MSigDB_Hallmark_2020          Interferon Gamma Response   4/200
# 17  MSigDB_Hallmark_2020                    heme Metabolism   4/200
# 18  MSigDB_Hallmark_2020                  KRAS Signaling Dn   4/200
# 19  MSigDB_Hallmark_2020            Cholesterol Homeostasis    2/74
#
#          P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0   1.711404e-08      3.593949e-07            0                     0
# 1   1.711404e-08      3.593949e-07            0                     0
# 2   1.417827e-06      1.984958e-05            0                     0
# 3   1.183168e-05      1.242327e-04            0                     0
# 4   8.411137e-05      7.065355e-04            0                     0
# 5   1.409499e-04      9.866496e-04            0                     0
# 6   5.271728e-04      3.163037e-03            0                     0
# 7   6.912718e-04      3.629177e-03            0                     0
# 8   2.873553e-03      1.340991e-02            0                     0
# 9   5.122704e-03      2.151536e-02            0                     0
# 10  1.339076e-02      4.326247e-02            0                     0
# 11  1.339076e-02      4.326247e-02            0                     0
# 12  1.339076e-02      4.326247e-02            0                     0
# 13  2.624040e-02      7.872121e-02            0                     0
# 14  3.490281e-02      9.772788e-02            0                     0
# 15  5.218540e-02      1.153572e-01            0                     0
# 16  5.218540e-02      1.153572e-01            0                     0
# 17  5.218540e-02      1.153572e-01            0                     0
# 18  5.218540e-02      1.153572e-01            0                     0
# 19  9.490482e-02      1.993001e-01            0                     0
#
#     Odds Ratio  Combined Score  \
# 0     9.809840      175.432970
# 1     9.809840      175.432970
# 2     8.006105      107.813291
# 3     7.074897       80.262794
# 4     6.208333       58.255081
# 5     6.734792       59.718108
# 6     5.363240       40.481637
# 7     7.705653       56.073863
# 8     4.539006       26.563199
# 9     4.770516       25.160047
# 10    3.735043       16.109949
# 11    3.735043       16.109949
# 12    3.735043       16.109949
# 13    8.450980       30.765414
# 14    7.181159       24.094138
# 15    2.950780        8.713514
# 16    2.950780        8.713514
# 17    2.950780        8.713514
# 18    2.950780        8.713514
# 19    3.983092        9.379706
#
#                                                 Genes
# 0   LAD1;ABLIM1;CCND1;MYC;KRT8;KRT13;AQP3;TOB1;KLK...
# 1   ST14;CDKN1A;CCND2;ITGB4;PERP;PDGFA;NUPR1;IFI30...
# 2   CCND2;GSTO1;MYC;CTSZ;NDRG1;SMPDL3A;DHRS3;CD44;...
# 3    ST14;CCND1;FABP5;PERP;KRT13;EMP2;TOB1;KLK10;CD44
# 4     PCOLCE2;PMEPA1;PCOLCE;EMP3;FBLN2;SAT1;CD44;TGM2
# 5              CDKN1A;CCND2;CCND1;GCH1;LMNA;SAT1;CD44
# 6              CDKN1A;CCND1;GCH1;MYC;PMEPA1;SAT1;CD44
# 7                        CCND1;KRT8;PMEPA1;SAT1;NDRG1
# 8               ALDH3A1;GCH1;DDAH2;GSTO1;FETUB;SPINT2
# 9                            GCH1;FGF18;CLTB;GGH;AQP3
# 10                       EFNA3;CDKN1A;PKP1;NDRG1;TGM2
# 11                       CDKN1A;PPA1;NUPR1;IFI30;CTSC
# 12                          CDKN1A;GCH1;CCL7;MYC;EMP3
# 13                                        CCND2;PDGFA
# 14                                          CCND2;MYC
# 15                           ABLIM1;CDKN1A;MYL7;ITGB4
# 16                             CDKN1A;GCH1;CCL7;IFI30
# 17                               MGST3;AQP3;TNS1;CTSB
# 18                          KRT13;PKP1;ALOX12B;LGALS7
# 19                                        FABP5;ANXA5

# %%
# Enriched terms among the stem cell drivers

enr = gseapy.enrichr(
    gene_list=list(shared_stem_cell_drivers),
    gene_sets='MSigDB_Hallmark_2020',
    organism='mouse',
    outdir=None
)
enr.res2d.sort_values('Adjusted P-value').head(20)
# Out:
#                 Gene_set                               Term Overlap   P-value  \
# 0   MSigDB_Hallmark_2020               IL-2/STAT5 Signaling   5/199  0.000665
# 1   MSigDB_Hallmark_2020          Interferon Alpha Response    3/97  0.004786
# 2   MSigDB_Hallmark_2020      TNF-alpha Signaling via NF-kB   4/200  0.005320
# 3   MSigDB_Hallmark_2020                            Hypoxia   4/200  0.005320
# 4   MSigDB_Hallmark_2020                    G2-M Checkpoint   4/200  0.005320
# 5   MSigDB_Hallmark_2020                       Adipogenesis   4/200  0.005320
# 6   MSigDB_Hallmark_2020                        E2F Targets   4/200  0.005320
# 7   MSigDB_Hallmark_2020          Oxidative Phosphorylation   4/200  0.005320
# 8   MSigDB_Hallmark_2020                          Apoptosis   3/161  0.018915
# 9   MSigDB_Hallmark_2020          Interferon Gamma Response   3/200  0.033070
# 10  MSigDB_Hallmark_2020                   mTORC1 Signaling   3/200  0.033070
# 11  MSigDB_Hallmark_2020                    heme Metabolism   3/200  0.033070
# 12  MSigDB_Hallmark_2020               Bile Acid Metabolism   2/112  0.058681
# 13  MSigDB_Hallmark_2020                    Spermatogenesis   2/135  0.081176
# 14  MSigDB_Hallmark_2020                    Notch Signaling    1/32  0.106209
# 15  MSigDB_Hallmark_2020                     Apical Surface    1/44  0.143102
# 16  MSigDB_Hallmark_2020                    Mitotic Spindle   2/199  0.153865
# 17  MSigDB_Hallmark_2020            Estrogen Response Early   2/200  0.155085
# 18  MSigDB_Hallmark_2020                         Myogenesis   2/200  0.155085
# 19  MSigDB_Hallmark_2020  Epithelial Mesenchymal Transition   2/200  0.155085
#
#     Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0           0.023259            0                     0    7.825535
# 1           0.023275            0                     0    9.448714
# 2           0.023275            0                     0    6.102041
# 3           0.023275            0                     0    6.102041
# 4           0.023275            0                     0    6.102041
# 5           0.023275            0                     0    6.102041
# 6           0.023275            0                     0    6.102041
# 7           0.023275            0                     0    6.102041
# 8           0.073557            0                     0    5.603250
# 9           0.096455            0                     0    4.485113
# 10          0.096455            0                     0    4.485113
# 11          0.096455            0                     0    4.485113
# 12          0.157986            0                     0    5.299465
# 13          0.202941            0                     0    4.377930
# 14          0.247821            0                     0    9.302945
# 15          0.251406            0                     0    6.702730
# 16          0.251406            0                     0    2.946103
# 17          0.251406            0                     0    2.931075
# 18          0.251406            0                     0    2.931075
# 19          0.251406            0                     0    2.931075
#
#     Combined Score                             Genes
# 0        57.254877  GPX4;GADD45B;CCNE1;GLIPR2;SLC2A3
# 1        50.475959                  RNF31;PSME2;LY6E
# 2        31.952121       TSC22D1;GADD45B;SLC2A3;KLF2
# 3        31.952121        CSRP2;CITED2;SLC2A1;SLC2A3
# 4        31.952121             CCNB2;MTF2;CCNF;LMNB1
# 5        31.952121              PHYH;GPX4;UCP2;G3BP2
# 6        31.952121           CCNB2;CCNE1;CENPM;LMNB1
# 7        31.952121         PHYH;GPX4;SLC25A20;ATP1B1
# 8        22.232693                GPX4;GADD45B;HSPB1
# 9        15.290281                  RNF31;PSME2;LY6E
# 10       15.290281                CCNF;SLC2A1;SLC2A3
# 11       15.290281                 UCP2;SLC2A1;BLVRB
# 12       15.027399                      PHYH;TFCP2L1
# 13       10.993556                        TLE4;CCNB2
# 14       20.860428                            TCF7L2
# 15       13.031445                             HSPB1
# 16        5.514166                       CCNB2;LMNB1
# 17        5.462887                      SLC2A1;BLVRB
# 18        5.462887                    GADD45B;COX7A1
# 19        5.462887                       GADD45B;FN1

# %% [markdown]
# ## Cell types

# %%
# Enriched terms among the dead-end drivers

enr = gseapy.enrichr(
    gene_list=list(shared_dead_end_drivers),
    gene_sets='PanglaoDB_Augmented_2021',
    organism='mouse',
    outdir=None
)
enr.res2d.sort_values('Adjusted P-value').head(20)
# Out:
#                     Gene_set                             Term Overlap  \
# 0   PanglaoDB_Augmented_2021                    Keratinocytes  14/127
# 1   PanglaoDB_Augmented_2021           Trophoblast Stem Cells   11/99
# 2   PanglaoDB_Augmented_2021                      Trichocytes  11/103
# 3   PanglaoDB_Augmented_2021         Mammary Epithelial Cells  12/134
# 4   PanglaoDB_Augmented_2021         Luminal Epithelial Cells  12/140
# 5   PanglaoDB_Augmented_2021                 Epithelial Cells  14/218
# 6   PanglaoDB_Augmented_2021                Trophoblast Cells  11/130
# 7   PanglaoDB_Augmented_2021            Salivary Mucous Cells   9/105
# 8   PanglaoDB_Augmented_2021                      Basal Cells  10/141
# 9   PanglaoDB_Augmented_2021                  Microfold Cells   9/126
# 10  PanglaoDB_Augmented_2021                        Sebocytes   8/124
# 11  PanglaoDB_Augmented_2021  Pulmonary Alveolar Type I Cells   8/131
# 12  PanglaoDB_Augmented_2021                   Cholangiocytes   8/134
# 13  PanglaoDB_Augmented_2021                  Principal Cells   8/136
# 14  PanglaoDB_Augmented_2021              Gastric Chief Cells   7/109
# 15  PanglaoDB_Augmented_2021                     Ductal Cells   7/132
# 16  PanglaoDB_Augmented_2021                   Foveolar Cells   6/114
# 17  PanglaoDB_Augmented_2021              Myoepithelial Cells   6/115
# 18  PanglaoDB_Augmented_2021              Airway Goblet Cells   6/118
# 19  PanglaoDB_Augmented_2021                     Hepatoblasts   5/114
#
#          P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0   2.763190e-13      2.928982e-11            0                     0
# 1   9.905232e-11      4.628763e-09            0                     0
# 2   1.530580e-10      4.628763e-09            0                     0
# 3   1.746703e-10      4.628763e-09            0                     0
# 4   2.915757e-10      6.181405e-09            0                     0
# 5   4.269618e-10      7.542991e-09            0                     0
# 6   1.900070e-09      2.877248e-08            0                     0
# 7   5.296982e-08      6.815224e-07            0                     0
# 8   5.786511e-08      6.815224e-07            0                     0
# 9   2.564149e-07      2.717998e-06            0                     0
# 10  2.622158e-06      2.526807e-05            0                     0
# 11  3.954496e-06      3.493138e-05            0                     0
# 12  4.680406e-06      3.816331e-05            0                     0
# 13  5.224594e-06      3.955764e-05            0                     0
# 14  1.164635e-05      8.230086e-05            0                     0
# 15  4.030971e-05      2.670518e-04            0                     0
# 16  1.516097e-04      9.365975e-04            0                     0
# 17  1.590449e-04      9.365975e-04            0                     0
# 18  1.830952e-04      1.021478e-03            0                     0
# 19  1.246843e-03      6.608267e-03            0                     0
#
#     Odds Ratio  Combined Score  \
# 0    19.416912      561.483136
# 1    19.158915      441.332745
# 2    18.322211      414.085711
# 3    15.167520      340.785685
# 4    14.452148      317.307344
# 5    10.705882      230.972203
# 6    14.145723      284.065580
# 7    14.144084      236.963527
# 8    11.584850      193.063281
# 9    11.593071      175.941881
# 10   10.315569      132.570673
# 11    9.725055      120.986083
# 12    9.492063      116.487796
# 13    9.342803      113.628417
# 14   10.195046      115.821008
# 15    8.309474       84.082885
# 16    8.189055       72.016192
# 17    8.113515       70.963433
# 18    7.894989       67.940366
# 19    6.711179       44.878598
#
#                                                 Genes
# 0   LAD1;ITGB4;KRT13;OVOL1;AQP3;SLURP1;KRT16;PERP;...
# 1   DSP;CCND1;CRABP2;KRT16;PERP;KRT8;EMP2;S100A14;...
# 2   DSP;LAD1;GPRC5A;S100A16;ITGB4;KRT16;PERP;KRT8;...
# 3   DSP;LAD1;S100A16;ITGB4;KRT16;PERP;KRT8;S100A14...
# 4   DSP;LAD1;ST14;ITGB4;PERP;KRT8;S100A14;OVOL1;NE...
# 5   LAD1;ST14;DGAT2;ITGB4;KRT8;KRT13;OVOL1;AQP3;KL...
# 6   LAD1;GPRC5A;SMAGP;KRT16;PERP;PLEK2;ANXA8;S100A...
# 7   KRT16;PKP1;ANXA8;EMP2;NUPR1;S100A14;NECTIN4;LG...
# 8   LAD1;S100A16;KRT16;ITGB4;PERP;LMNA;PKP1;PLEK2;...
# 9   LAD1;ST14;FABP5;CTSZ;ANXA5;TMBIM1;IFI30;SAT1;CTSB
# 10     LAD1;ST14;KRT16;PLEK2;S100A14;OVOL1;AQP3;AP1M2
# 11    DSP;GPRC5A;S100A16;ITGB4;PERP;EMP2;S100A14;AQP3
# 12      LAD1;ST14;ITGB4;KRT8;S100A14;OVOL1;MISP;AP1M2
# 13     DSP;LAD1;ITGB4;S100A14;OVOL1;AQP3;AP1M2;ZBTB7C
# 14            DSP;LAD1;ST14;TPPP3;ITGB4;S100A14;AP1M2
# 15            DSP;LAD1;S100A16;PERP;KRT8;S100A14;MISP
# 16              ALDH3A1;LAD1;GPRC5A;KRT8;S100A14;MISP
# 17                DSP;S100A16;KRT16;PERP;PKP1;S100A14
# 18                LAD1;GGH;S100A14;NECTIN4;MISP;AP1M2
# 19                        DSP;LAD1;KRT8;S100A14;AP1M2

# %%
# Enriched terms among the stem cell drivers

enr = gseapy.enrichr(
    gene_list=list(shared_stem_cell_drivers),
    gene_sets='PanglaoDB_Augmented_2021',
    organism='mouse',
    outdir=None
)
enr.res2d.sort_values('Adjusted P-value').head(20)
# Out:
#                     Gene_set                              Term Overlap  \
# 0   PanglaoDB_Augmented_2021                    Epiblast Cells   5/109
# 1   PanglaoDB_Augmented_2021            Pluripotent Stem Cells   4/112
# 2   PanglaoDB_Augmented_2021              Embryonic Stem Cells   4/176
# 3   PanglaoDB_Augmented_2021                        Osteocytes    3/98
# 4   PanglaoDB_Augmented_2021                       Fibroblasts   4/232
# 5   PanglaoDB_Augmented_2021                      Chondrocytes   3/146
# 6   PanglaoDB_Augmented_2021                  His Bundle Cells    2/98
# 7   PanglaoDB_Augmented_2021           Kidney Progenitor Cells   2/105
# 8   PanglaoDB_Augmented_2021                Adrenergic Neurons   2/106
# 9   PanglaoDB_Augmented_2021                         Ionocytes   2/107
# 10  PanglaoDB_Augmented_2021  Cardiac Stem And Precursor Cells   2/113
# 11  PanglaoDB_Augmented_2021       Pancreatic Progenitor Cells   2/114
# 12  PanglaoDB_Augmented_2021        Adipocyte Progenitor Cells   2/115
# 13  PanglaoDB_Augmented_2021                       Delta Cells   2/131
# 14  PanglaoDB_Augmented_2021                       Melanocytes   2/133
# 15  PanglaoDB_Augmented_2021               Distal Tubule Cells   2/137
# 16  PanglaoDB_Augmented_2021                         Microglia   2/158
# 17  PanglaoDB_Augmented_2021                          Myocytes   2/163
# 18  PanglaoDB_Augmented_2021               Smooth Muscle Cells   2/169
# 19  PanglaoDB_Augmented_2021                         Monocytes   2/176
#
#      P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0   0.000040          0.002722            0                     0   14.664201
# 1   0.000643          0.021858            0                     0   11.123457
# 2   0.003382          0.076664            0                     0    6.961945
# 3   0.004925          0.083720            0                     0    9.348782
# 4   0.008900          0.121046            0                     0    5.237108
# 5   0.014608          0.165557            0                     0    6.195700
# 6   0.046280          0.321551            0                     0    6.076593
# 7   0.052347          0.321551            0                     0    5.661622
# 8   0.053236          0.321551            0                     0    5.606900
# 9   0.054130          0.321551            0                     0    5.553221
# 10  0.059606          0.321551            0                     0    5.251457
# 11  0.060537          0.321551            0                     0    5.204307
# 12  0.061473          0.321551            0                     0    5.157991
# 13  0.077093          0.353782            0                     0    4.514592
# 14  0.079126          0.353782            0                     0    4.445218
# 15  0.083243          0.353782            0                     0    4.312636
# 16  0.105858          0.416860            0                     0    3.728130
# 17  0.111467          0.416860            0                     0    3.611436
# 18  0.118298          0.416860            0                     0    3.480627
# 19  0.126398          0.416860            0                     0    3.339419
#
#     Combined Score                          Genes
# 0       148.488266  TRIM71;MYCN;PHC1;DNMT3B;L1TD1
# 1        81.752191        MSH6;TRIM71;CCNF;DNMT3B
# 2        39.607998        ENAH;ZFP42;DNMT3B;L1TD1
# 3        49.674680              ENAH;TCF7L1;CSRP2
# 4        24.727794           UCP2;FN1;COX7A1;KLF2
# 5        26.184199               GADD45B;FN1;NID1
# 6        18.673710                     ENAH;CSRP2
# 7        16.701033                     ENAH;SALL1
# 8        16.445200                     MYCN;FXYD6
# 9        16.195244                 TFCP2L1;ATP1B1
# 10       14.809069                       ENAH;FN1
# 11       14.595465                    ENAH;ATP1B1
# 12       14.386448                    ENAH;TCF7L1
# 13       11.569733                    UCP2;ATP1B1
# 14       11.276227                      FN1;HSPB1
# 15       10.721180                 TFCP2L1;ATP1B1
# 16        8.372088                     SALL1;UCP2
# 17        7.923593                    NID1;COX7A1
# 18        7.429567                  RBPMS2;COX7A1
# 19        6.906991                       FN1;LY6E

# %% [markdown]
# # Check which driver targets are transcription factors

# %% [markdown]
# Source for list of transcription factors: https://guolab.wchscu.cn/AnimalTFDB#!/download

# %%
tf_df = pandas.read_csv("ChIP Sequencing Data/Mus_musculus_TF.txt", sep="\t")
tf_array = tf_df["Symbol"].to_numpy()

# %%
# Dead end drivers which are TFs

shared_dead_end_tfs = numpy.intersect1d(shared_dead_end_drivers, tf_array)
shared_dead_end_tfs
# Out:
# array(['Barx2', 'Hoxa7', 'Myc', 'Ovol1', 'Phox2a', 'Tlx2', 'Tshz1',
#        'Zbtb7c'], dtype=object)

# %% [markdown]
# Ovol1 is the most interesting target. Cdh1 also looks like it could be a Hic2 target, but the narrowpeak file has removed the peak, likely due to a low q-value. The narrowpeak also does not list the peak for Klf4 even though it is a known target of Klf4.

# %%
# Stem cell drivers which are TFs

shared_stem_cell_tfs = numpy.intersect1d(shared_stem_cell_drivers, tf_array)
shared_stem_cell_tfs
# Out:
# array(['Jarid2', 'Klf2', 'Mycn', 'Rest', 'Sall1', 'Tcf7l1', 'Tcf7l2',
#        'Tfcp2l1', 'Tsc22d1', 'Zfp42'], dtype=object)

# %% [markdown]
# Jarid2 is a strong driver that regulates differentiation of stem cells.

# %%
# Hic2 target TFs that are dead end drivers

dead_end_tfs = numpy.intersect1d(hic2_dead_end_drivers, tf_array)
dead_end_tfs
# Out:
# array(['Barx2', 'Dmrtc2', 'Hmgb3', 'Hoxa7', 'Myc', 'Ovol1', 'Phox2a',
#        'Tlx2', 'Tshz1', 'Zbtb7c'], dtype=object)

# %%
# Hic2 target TFs that are stem cell drivers

stem_cell_tfs = numpy.intersect1d(hic2_stem_cell_drivers, tf_array)
stem_cell_tfs
# Out:
# array(['Jarid2', 'Klf2', 'Mycn', 'Rest', 'Sall1', 'Tcf7l1', 'Tcf7l2',
#        'Tfcp2l1', 'Tsc22d1', 'Zfp42'], dtype=object)

# %%
# Find all Hic2 targets that are transcription factors among the variable genes

hic2_target_tfs = numpy.intersect1d(hic2_targets, tf_array)
variable_hic2_target_tfs = numpy.intersect1d(hic2_target_tfs, adata.var_names.to_numpy())
variable_hic2_target_tfs
# Out:
# array(['Arid3a', 'Atf5', 'Barx2', 'Creb3l1', 'Creb3l2', 'Dbp', 'Ddit3',
#        'Dmrtc2', 'Egr1', 'Ehf', 'En1', 'Fos', 'Fosb', 'Fosl1', 'Fosl2',
#        'Foxp2', 'Gata2', 'Gata6', 'Hand1', 'Hic2', 'Hmga2', 'Hmgb3',
#        'Hopx', 'Hoxa10', 'Hoxa7', 'Id2', 'Id3', 'Irx1', 'Irx3', 'Jarid2',
#        'Junb', 'Klf10', 'Klf2', 'Klf4', 'Klf5', 'Klf6', 'Klf7', 'Lhx9',
#        'Lin28a', 'Meis2', 'Meox2', 'Msc', 'Myc', 'Mycn', 'Nfil3', 'Nfix',
#        'Nr2f1', 'Nr4a1', 'Ovol1', 'Pax8', 'Peg3', 'Phox2a', 'Pou5f1',
#        'Prrx1', 'Prrx2', 'Rest', 'Runx1', 'Sall1', 'Setbp1', 'Smad7',
#        'Snai2', 'Sox9', 'Stat2', 'Tbx3', 'Tcf4', 'Tcf7l1', 'Tcf7l2',
#        'Tfap2c', 'Tfcp2l1', 'Tfdp2', 'Tlx2', 'Tlx3', 'Tox', 'Tsc22d1',
#        'Tshz1', 'Tshz2', 'Twist1', 'Twist2', 'Zbtb20', 'Zbtb7c', 'Zeb2',
#        'Zfat', 'Zfhx3', 'Zfp296', 'Zfp36l1', 'Zfp42', 'Zfp503', 'Zfp710',
#        'Zim1', 'Zmiz1'], dtype=object)

# %%
# Find all shared targets that are transcription factors among the variable genes

shared_target_tfs = numpy.intersect1d(shared_targets, tf_array)
variable_shared_target_tfs = numpy.intersect1d(shared_target_tfs, adata.var_names.to_numpy())
variable_shared_target_tfs
# Out:
# array(['Arid3a', 'Atf5', 'Barx2', 'Creb3l1', 'Creb3l2', 'Dbp', 'Ddit3',
#        'Egr1', 'Ehf', 'En1', 'Fos', 'Fosb', 'Fosl1', 'Fosl2', 'Gata2',
#        'Gata6', 'Hic2', 'Hmga2', 'Hoxa7', 'Id2', 'Id3', 'Irx1', 'Irx3',
#        'Jarid2', 'Junb', 'Klf10', 'Klf2', 'Klf4', 'Klf5', 'Klf7', 'Lhx9',
#        'Lin28a', 'Msc', 'Myc', 'Mycn', 'Nfil3', 'Nfix', 'Nr2f1', 'Nr4a1',
#        'Ovol1', 'Peg3', 'Phox2a', 'Pou5f1', 'Prrx1', 'Rest', 'Sall1',
#        'Setbp1', 'Smad7', 'Snai2', 'Stat2', 'Tbx3', 'Tcf4', 'Tcf7l1',
#        'Tcf7l2', 'Tfap2c', 'Tfcp2l1', 'Tfdp2', 'Tlx2', 'Tlx3', 'Tox',
#        'Tsc22d1', 'Tshz1', 'Tshz2', 'Twist1', 'Twist2', 'Zbtb20',
#        'Zbtb7c', 'Zeb2', 'Zfat', 'Zfhx3', 'Zfp296', 'Zfp36l1', 'Zfp42',
#        'Zfp503', 'Zfp710', 'Zim1', 'Zmiz1'], dtype=object)

# %%
# Rank all Hic2 targets by correlation with cell fates

# Top dead end drivers
driver_df.loc[variable_hic2_target_tfs].sort_values("Day 12 Control_corr", ascending=False).query("`Day 12 Control_corr` > 0")
# Out:
#             Day 12 Control_corr  Day 12 Control_pval  Day 12 Control_qval  \
# gene_names
# Tlx2                   0.479131         0.000000e+00         0.000000e+00
# Ovol1                  0.443451         0.000000e+00         0.000000e+00
# Dmrtc2                 0.442656         0.000000e+00         0.000000e+00
# Zbtb7c                 0.357499        1.331287e-292        1.399253e-291
# Myc                    0.348143        3.048684e-276        3.044111e-275
# Phox2a                 0.309353        1.553848e-214        1.179861e-213
# Hmgb3                  0.252692        1.250345e-140        6.257992e-140
# Tshz1                  0.221711        1.272706e-107        5.273017e-107
# Barx2                  0.219635        1.381949e-105        5.620677e-105
# Hoxa7                  0.217475        1.721733e-103        6.960124e-103
# Klf10                  0.213486         1.106383e-99         4.392540e-99
# Runx1                  0.210680         4.732970e-97         1.856924e-96
# Tlx3                   0.202168         2.627142e-89         9.917584e-89
# Twist2                 0.187986         3.478873e-77         1.216692e-76
# Fosl1                  0.181717         3.916786e-72         1.314592e-71
# Hopx                   0.181668         4.276751e-72         1.430598e-71
# Atf5                   0.168311         5.946601e-62         1.835450e-61
# Junb                   0.157864         1.351505e-54         3.951620e-54
# Gata2                  0.152062         1.000605e-50         2.854582e-50
# Zfp296                 0.148351         2.488022e-48         6.978343e-48
# Zfhx3                  0.137915         6.296605e-42         1.678815e-41
# Hmga2                  0.134196         9.185265e-40         2.407214e-39
# Fosl2                  0.125456         6.430473e-35         1.593257e-34
# Pax8                   0.125280         7.987416e-35         1.969243e-34
# Ehf                    0.120629         2.189244e-32         5.248809e-32
# Hoxa10                 0.112169         3.410419e-28         7.756955e-28
# Ddit3                  0.111471         7.324857e-28         1.656596e-27
# Klf4                   0.099717         1.382307e-22         2.939795e-22
# Nfix                   0.061490         1.767393e-09         2.996166e-09
# En1                    0.061071         2.275697e-09         3.841561e-09
# Nr4a1                  0.057964         1.411440e-08         2.344964e-08
# Tshz2                  0.046806         4.686298e-06         7.232254e-06
# Nr2f1                  0.046353         5.787324e-06         8.869751e-06
# Prrx1                  0.043637         1.972335e-05         2.979390e-05
# Arid3a                 0.035364         5.440235e-04         7.726991e-04
# Twist1                 0.027149         7.947100e-03         1.065125e-02
# Pou5f1                 0.023705         2.047965e-02         2.652261e-02
# Meox2                  0.021434         3.613600e-02         4.538591e-02
# Zfp503                 0.012210         2.326770e-01         2.655178e-01
# Nfil3                  0.009556         3.502422e-01         3.894397e-01
# Zim1                   0.006982         4.949308e-01         5.322438e-01
# Foxp2                  0.003548         7.287227e-01         7.563188e-01
# Zeb2                   0.002055         8.408309e-01         8.577823e-01
#
#             Day 12 Control_ci_low  Day 12 Control_ci_high  mESC_corr  \
# gene_names
# Tlx2                     0.463534                0.494430  -0.479133
# Ovol1                    0.427200                0.459416  -0.443452
# Dmrtc2                   0.426391                0.458635  -0.442655
# Zbtb7c                   0.339886                0.374861  -0.357488
# Myc                      0.330400                0.365640  -0.348143
# Phox2a                   0.291109                0.327371  -0.309352
# Hmgb3                    0.233827                0.271366  -0.252703
# Tshz1                    0.202562                0.240691  -0.221707
# Barx2                    0.200469                0.238634  -0.219635
# Hoxa7                    0.198290                0.236493  -0.217468
# Klf10                    0.194268                0.232540  -0.213494
# Runx1                    0.191439                0.229759  -0.210680
# Tlx3                     0.182860                0.221320  -0.202170
# Twist2                   0.168572                0.207254  -0.187984
# Fosl1                    0.162259                0.201033  -0.181716
# Hopx                     0.162210                0.200985  -0.181670
# Atf5                     0.148764                0.187727  -0.168319
# Junb                     0.138252                0.177352  -0.157861
# Gata2                    0.132417                0.171588  -0.152062
# Zfp296                   0.128684                0.167900  -0.148343
# Zfhx3                    0.118192                0.157528  -0.137910
# Hmga2                    0.114455                0.153831  -0.134232
# Fosl2                    0.105673                0.145141  -0.125456
# Pax8                     0.105496                0.144965  -0.125280
# Ehf                      0.100824                0.140339  -0.120629
# Hoxa10                   0.092328                0.131922  -0.112170
# Ddit3                    0.091627                0.131227  -0.111471
# Klf4                     0.079827                0.119527  -0.099716
# Nfix                     0.041491                0.081438  -0.061485
# En1                      0.041072                0.081021  -0.061069
# Nr4a1                    0.037959                0.077922  -0.057956
# Tshz2                    0.026782                0.066792  -0.046807
# Nr2f1                    0.026328                0.066341  -0.046353
# Prrx1                    0.023609                0.063631  -0.043637
# Arid3a                   0.015326                0.055374  -0.035356
# Twist1                   0.007104                0.047172  -0.027147
# Pou5f1                   0.003657                0.043733  -0.023700
# Meox2                    0.001386                0.041466  -0.021434
# Zfp503                  -0.007841                0.032251  -0.012209
# Nfil3                   -0.010495                0.029600  -0.009556
# Zim1                    -0.013069                0.027028  -0.006982
# Foxp2                   -0.016502                0.023596  -0.003548
# Zeb2                    -0.017995                0.022103  -0.002054
#
#                 mESC_pval      mESC_qval  mESC_ci_low  mESC_ci_high
# gene_names
# Tlx2         0.000000e+00   0.000000e+00    -0.494432     -0.463536
# Ovol1        0.000000e+00   0.000000e+00    -0.459416     -0.427201
# Dmrtc2       0.000000e+00   0.000000e+00    -0.458634     -0.426390
# Zbtb7c      1.391397e-292  1.462431e-291    -0.374851     -0.339875
# Myc         3.053154e-276  3.048575e-275    -0.365640     -0.330400
# Phox2a      1.555514e-214  1.181126e-213    -0.327371     -0.291109
# Hmgb3       1.214356e-140  6.077865e-140    -0.271377     -0.233839
# Tshz1       1.285934e-107  5.327824e-107    -0.240686     -0.202558
# Barx2       1.381681e-105  5.619586e-105    -0.238634     -0.200469
# Hoxa7       1.746736e-103  7.061196e-103    -0.236487     -0.198284
# Klf10        1.088342e-99   4.320914e-99    -0.232547     -0.194276
# Runx1        4.732427e-97   1.856710e-96    -0.229759     -0.191440
# Tlx3         2.618684e-89   9.885658e-89    -0.221322     -0.182862
# Twist2       3.492253e-77   1.221371e-76    -0.207252     -0.168570
# Fosl1        3.924378e-72   1.317140e-71    -0.201032     -0.162257
# Hopx         4.267268e-72   1.427426e-71    -0.200987     -0.162211
# Atf5         5.867239e-62   1.810955e-61    -0.187735     -0.148772
# Junb         1.357699e-54   3.969729e-54    -0.177349     -0.138249
# Gata2        1.001289e-50   2.856535e-50    -0.171588     -0.132416
# Zfp296       2.514734e-48   7.053265e-48    -0.167893     -0.128677
# Zfhx3        6.334689e-42   1.688969e-41    -0.157524     -0.118188
# Hmga2        8.755642e-40   2.294622e-39    -0.153868     -0.114491
# Fosl2        6.431998e-35   1.593635e-34    -0.145140     -0.105673
# Pax8         7.987877e-35   1.969357e-34    -0.144965     -0.105496
# Ehf          2.191085e-32   5.259131e-32    -0.140338     -0.100823
# Hoxa10       3.405320e-28   7.745358e-28    -0.131923     -0.092329
# Ddit3        7.325466e-28   1.656733e-27    -0.131227     -0.091627
# Klf4         1.382732e-22   2.940698e-22    -0.119526     -0.079827
# Nfix         1.772098e-09   3.004143e-09    -0.081434     -0.041487
# En1          2.278515e-09   3.846317e-09    -0.081019     -0.041070
# Nr4a1        1.417949e-08   2.355777e-08    -0.077914     -0.037951
# Tshz2        4.684809e-06   7.229957e-06    -0.066793     -0.026782
# Nr2f1        5.786959e-06   8.869191e-06    -0.066341     -0.026329
# Prrx1        1.972754e-05   2.980023e-05    -0.063630     -0.023608
# Arid3a       5.456454e-04   7.750028e-04    -0.055366     -0.015318
# Twist1       7.951080e-03   1.065658e-02    -0.047171     -0.007102
# Pou5f1       2.050683e-02   2.655780e-02    -0.043728     -0.003652
# Meox2        3.613864e-02   4.538922e-02    -0.041465     -0.001385
# Zfp503       2.327219e-01   2.656142e-01    -0.032250      0.007843
# Nfil3        3.502854e-01   3.894877e-01    -0.029599      0.010496
# Zim1         4.949420e-01   5.322558e-01    -0.027027      0.013069
# Foxp2        7.287504e-01   7.565431e-01    -0.023595      0.016502
# Zeb2         8.408794e-01   8.577763e-01    -0.022102      0.017996

# %%
# Top stem cell drivers
driver_df.loc[variable_hic2_target_tfs].sort_values("Day 12 Control_corr", ascending=True).query("`Day 12 Control_corr` < 0")
# Out:
#             Day 12 Control_corr  Day 12 Control_pval  Day 12 Control_qval  \
# gene_names
# Jarid2                -0.503917         0.000000e+00         0.000000e+00
# Zfp42                 -0.467963         0.000000e+00         0.000000e+00
# Tcf7l1                -0.431665         0.000000e+00         0.000000e+00
# Rest                  -0.388086         0.000000e+00         0.000000e+00
# Klf2                  -0.369636         0.000000e+00         0.000000e+00
# Mycn                  -0.331331        2.573182e-248        2.214933e-247
# Sall1                 -0.303264        1.055759e-205        7.583996e-205
# Tfcp2l1               -0.301656        2.083991e-203        1.465398e-202
# Tsc22d1               -0.291699        1.552001e-189        1.029683e-188
# Tcf7l2                -0.282169        8.488035e-177        5.264163e-176
# Tfap2c                -0.267587        2.624040e-158        1.471968e-157
# Tfdp2                 -0.246438        1.455925e-133        6.972377e-133
# Peg3                  -0.195793         9.739647e-84         3.542819e-83
# Fos                   -0.187753         5.399120e-77         1.881683e-76
# Hic2                  -0.185105         7.682067e-75         2.640463e-74
# Smad7                 -0.181598         4.863476e-72         1.624141e-71
# Klf6                  -0.171746         1.759227e-64         5.567631e-64
# Zfp36l1               -0.152007         1.087432e-50         3.097862e-50
# Klf7                  -0.137612         9.490920e-42         2.527116e-41
# Msc                   -0.135434         1.777300e-40         4.676243e-40
# Tbx3                  -0.128430         1.575903e-36         3.993754e-36
# Id2                   -0.118433         2.875643e-31         6.796047e-31
# Lin28a                -0.111019         1.199140e-27         2.705857e-27
# Stat2                 -0.106976         8.961696e-26         1.975332e-25
# Zfp710                -0.099141         2.418893e-22         5.127951e-22
# Hand1                 -0.098779         3.434436e-22         7.242416e-22
# Dbp                   -0.093660         4.245506e-20         8.686759e-20
# Fosb                  -0.091370         3.369552e-19         6.783262e-19
# Id3                   -0.089496         1.767158e-18         3.536086e-18
# Zbtb20                -0.088315         4.935412e-18         9.846171e-18
# Klf5                  -0.078342         1.676622e-14         3.167657e-14
# Creb3l2               -0.076587         6.351193e-14         1.190923e-13
# Tcf4                  -0.050812         6.664154e-07         1.067227e-06
# Creb3l1               -0.050552         7.597000e-07         1.212727e-06
# Zfat                  -0.048667         1.928803e-06         3.028161e-06
# Egr1                  -0.048485         2.107027e-06         3.297597e-06
# Setbp1                -0.047432         3.488708e-06         5.417535e-06
# Snai2                 -0.037240         2.708679e-04         3.916895e-04
# Gata6                 -0.036490         3.592866e-04         5.165553e-04
# Meis2                 -0.033619         1.011639e-03         1.423709e-03
# Zmiz1                 -0.031559         2.030310e-03         2.815645e-03
# Lhx9                  -0.020200         4.830178e-02         5.980078e-02
# Prrx2                 -0.016500         1.067547e-01         1.276581e-01
# Tox                   -0.014260         1.633234e-01         1.905122e-01
# Sox9                  -0.013901         1.741917e-01         2.024801e-01
# Irx3                  -0.009040         3.768670e-01         4.158030e-01
# Irx1                  -0.003614         7.238686e-01         7.532911e-01
#
#             Day 12 Control_ci_low  Day 12 Control_ci_high  mESC_corr  \
# gene_names
# Jarid2                  -0.518726               -0.488807   0.503923
# Zfp42                   -0.483476               -0.452156   0.467972
# Tcf7l1                  -0.447839               -0.415210   0.431661
# Rest                    -0.404984               -0.370922   0.388094
# Klf2                    -0.386819               -0.352197   0.369637
# Mycn                    -0.349062               -0.313364   0.331331
# Sall1                   -0.321359               -0.284947   0.303265
# Tfcp2l1                 -0.319771               -0.283320   0.301657
# Tsc22d1                 -0.309936               -0.273248   0.291696
# Tcf7l2                  -0.300518               -0.263611   0.282163
# Tfap2c                  -0.286102               -0.248873   0.267588
# Tfdp2                   -0.265177               -0.227513   0.246442
# Peg3                    -0.214998               -0.176436   0.195793
# Fos                     -0.207023               -0.168337   0.187762
# Hic2                    -0.204396               -0.165671   0.185105
# Smad7                   -0.200915               -0.162139   0.181599
# Klf6                    -0.191137               -0.152221   0.171744
# Zfp36l1                 -0.171533               -0.132361   0.151998
# Klf7                    -0.157228               -0.117888   0.137612
# Msc                     -0.155062               -0.115699   0.135432
# Tbx3                    -0.148098               -0.108661   0.128430
# Id2                     -0.138154               -0.098618   0.118439
# Lin28a                  -0.130777               -0.091172   0.111025
# Stat2                   -0.126754               -0.087114   0.106977
# Zfp710                  -0.118954               -0.079250   0.099146
# Hand1                   -0.118593               -0.078886   0.098779
# Dbp                     -0.113496               -0.073749   0.093661
# Fosb                    -0.111216               -0.071452   0.091372
# Id3                     -0.109349               -0.069572   0.089499
# Zbtb20                  -0.108173               -0.068387   0.088317
# Klf5                    -0.098237               -0.058385   0.078337
# Creb3l2                 -0.096488               -0.056625   0.076588
# Tcf4                    -0.070789               -0.030794   0.050824
# Creb3l1                 -0.070530               -0.030534   0.050551
# Zfat                    -0.068650               -0.028646   0.048668
# Egr1                    -0.068468               -0.028464   0.048491
# Setbp1                  -0.067417               -0.027409   0.047432
# Snai2                   -0.057246               -0.017203   0.037241
# Gata6                   -0.056498               -0.016453   0.036490
# Meis2                   -0.053632               -0.013578   0.033626
# Zmiz1                   -0.051576               -0.011517   0.031559
# Lhx9                    -0.040233               -0.000151   0.020200
# Prrx2                   -0.036537                0.003550   0.016498
# Tox                     -0.034300                0.005790   0.014260
# Sox9                    -0.033941                0.006150   0.013901
# Irx3                    -0.029084                0.011011   0.009039
# Irx1                    -0.023662                0.016436   0.003615
#
#                 mESC_pval      mESC_qval  mESC_ci_low  mESC_ci_high
# gene_names
# Jarid2       0.000000e+00   0.000000e+00     0.488812      0.518731
# Zfp42        0.000000e+00   0.000000e+00     0.452165      0.483485
# Tcf7l1       0.000000e+00   0.000000e+00     0.415205      0.447834
# Rest         0.000000e+00   0.000000e+00     0.370931      0.404992
# Klf2         0.000000e+00   0.000000e+00     0.352198      0.386819
# Mycn        2.576527e-248  2.217812e-247     0.313363      0.349061
# Sall1       1.052735e-205  7.562272e-205     0.284948      0.321360
# Tfcp2l1     2.076892e-203  1.460406e-202     0.283321      0.319772
# Tsc22d1     1.567195e-189  1.039763e-188     0.273245      0.309933
# Tcf7l2      8.619147e-177  5.345477e-176     0.263606      0.300513
# Tfap2c      2.621497e-158  1.470542e-157     0.248874      0.286102
# Tfdp2       1.441297e-133  6.902326e-133     0.227517      0.265181
# Peg3         9.748694e-84   3.546110e-83     0.176436      0.214998
# Fos          5.307098e-77   1.849612e-76     0.168347      0.207032
# Hic2         7.680907e-75   2.640064e-74     0.165671      0.204396
# Smad7        4.851698e-72   1.620207e-71     0.162140      0.200917
# Klf6         1.764899e-64   5.585585e-64     0.152219      0.191135
# Zfp36l1      1.102161e-50   3.138869e-50     0.132352      0.171525
# Klf7         9.499008e-42   2.529269e-41     0.117888      0.157227
# Msc          1.781888e-40   4.688314e-40     0.115697      0.155060
# Tbx3         1.576959e-36   3.996431e-36     0.108660      0.148097
# Id2          2.854505e-31   6.746091e-31     0.098624      0.138160
# Lin28a       1.190817e-27   2.687076e-27     0.091179      0.130783
# Stat2        8.959911e-26   1.974938e-25     0.087114      0.126754
# Zfp710       2.408000e-22   5.104858e-22     0.079254      0.118959
# Hand1        3.433795e-22   7.241065e-22     0.078886      0.118594
# Dbp          4.242085e-20   8.679759e-20     0.073750      0.113497
# Fosb         3.364269e-19   6.772626e-19     0.071454      0.111217
# Id3          1.762085e-18   3.529473e-18     0.069575      0.109352
# Zbtb20       4.924934e-18   9.825269e-18     0.068389      0.108175
# Klf5         1.683929e-14   3.181462e-14     0.058379      0.098232
# Creb3l2      6.347104e-14   1.190157e-13     0.056625      0.096489
# Tcf4         6.624087e-07   1.060810e-06     0.030806      0.070801
# Creb3l1      7.603138e-07   1.213706e-06     0.030533      0.070529
# Zfat         1.928073e-06   3.027014e-06     0.028647      0.068650
# Egr1         2.101420e-06   3.288822e-06     0.028469      0.068473
# Setbp1       3.489003e-06   5.417993e-06     0.027409      0.067417
# Snai2        2.707159e-04   3.914698e-04     0.017205      0.057248
# Gata6        3.592702e-04   5.165318e-04     0.016453      0.056498
# Meis2        1.009004e-03   1.420001e-03     0.013586      0.053639
# Zmiz1        2.030350e-03   2.815700e-03     0.011517      0.051576
# Lhx9         4.830349e-02   5.980289e-02     0.000151      0.040233
# Prrx2        1.068058e-01   1.277193e-01    -0.003553      0.036535
# Tox          1.633245e-01   1.905135e-01    -0.005790      0.034300
# Sox9         1.742066e-01   2.024975e-01    -0.006150      0.033941
# Irx3         3.769206e-01   4.158621e-01    -0.011012      0.029083
# Irx1         7.238043e-01   7.532241e-01    -0.016435      0.023663

# %% [markdown]
# ## Trends of transcription factors

# %%
# Function for plotting trends independent of trajectory

def plot_grouped_gene_trend(adata, genes, group_key="group", time_key="latent_time", layer="X", groups=None, columns=4, figure_width=14, plot_height=4, n_splines=6):
    """
    Plots smoothed gene expression using generalized additive models (GAMs).
    This provides true smooth local regression with confidence intervals.
    """

    number_of_genes = len(genes)
    number_of_columns = min(columns, number_of_genes)
    
    # Calculate rows
    rows = (number_of_genes + number_of_columns - 1) // number_of_columns
    
    figure, axes = pyplot.subplots(rows, number_of_columns)
    figure.set_figwidth(figure_width)
    figure.set_figheight(plot_height * rows)

    # Handle single gene case (axes is not an array) and 1D array case
    if number_of_genes == 1:
        axes_flat = [axes]
    else:
        axes_flat = axes.flatten()

    # Define colors for groups
    unique_groups = adata.obs[group_key].unique()
    if f"{group_key}_colors" in adata.uns_keys():
        palette = adata.uns[f"{group_key}_colors"]
        color_map = dict(zip(unique_groups, palette))
    else:
        palette = seaborn.color_palette("tab10", n_colors=len(unique_groups))
        color_map = dict(zip(unique_groups, palette))


    for gene_index, gene in enumerate(genes):
        axis = axes_flat[gene_index]
        
        # Fetch expression data
        if layer == "raw":
            expr_data = adata.raw.to_adata()[:, gene].X
        elif layer == "X":
            expr_data = adata[:, gene].X
        else:
            expr_data = adata[:, gene].layers[layer]
        if hasattr(expr_data, "toarray"):
            expr_data = expr_data.toarray()
        expr_data = expr_data.flatten()
        
        # Create DataFrame
        df = pandas.DataFrame({
            "Latent Time": adata.obs[time_key],
            "Expression": expr_data,
            "Group": adata.obs[group_key]
        })
        
        # Determine which groups to plot
        if groups is None:
            # If no specific list, plot all groups found in the data
            plot_groups = df["Group"].unique()
        else:
            plot_groups = groups

        # Loop through each group and fit a GAM
        for group in plot_groups:
            group_data = df[df["Group"] == group]
            color = color_map[group]
            
            # Skip empty groups
            if len(group_data) < 10:
                continue

            # Prepare X and y for pygam
            X = group_data["Latent Time"].values.reshape(-1, 1)
            y = group_data["Expression"].values
            
            # Fit LinearGAM using a spline term s(0)
            gam = pygam.LinearGAM(pygam.s(0, n_splines=n_splines)).fit(X, y)
            
            # Greate grid
            X_grid = numpy.linspace(X.min(), X.max(), 500)
            
            # Predict values and confidence intervals
            y_pred = gam.predict(X_grid)
            confidence_intervals = gam.confidence_intervals(X_grid, width=0.95)
            
            # Plot line
            axis.plot(X_grid, y_pred, label=group, color=color, linewidth=3)
            
            # Plot confidence interval
            axis.fill_between(
                X_grid, 
                confidence_intervals[:, 0], 
                confidence_intervals[:, 1], 
                color=color, 
                alpha=0.2
            )

        axis.set_title(f"{gene} expression")
        axis.set_xlabel("Latent Time")
        
        # Add legend to the first plot
        if gene_index == 0:
            axis.legend()

    # Clean up empty subplots
    for i in range(number_of_genes, len(axes_flat)):
        axes_flat[i].axis('off')

    pyplot.tight_layout()
    pyplot.show()

# Define colors for all three groups

group_colors = [
    "#cbc9ca",
    "#0a652c",
    "#da2e24",
    "#3180bd",
]

adata.uns["group_colors"] = group_colors

control_indices = adata.obs["group"] == "control"
hic2_indices = adata.obs["group"] == "Hic2"
reprogramming_group_indices = (adata.obs["group"] == "control") | (adata.obs["group"] == "Hic2")

# %%
# Expression of dead end drivers

plot_grouped_gene_trend(
    adata, 
    list(dead_end_tfs)+ ["Hic2"], 
    group_key="group", 
    layer="spliced", 
    groups=["Hic2", "control"]
)

# %% [markdown]
# Ovol1, Cdh1, Tlx2, Zbtb7c and Hmgb3 have the largest differences in expression between the groups. Once again, Ovol1 looks most promising. Hoxa7 does not look like a driver since it changes late in the process where some control cells reach the dead end. Myc is repressed by Ovol1, but is also a target of Hic2. If Hic2 downregulates Myc, Hic2 reprogramming could benefit from more Myc OX.

# %%
# Expression of reprogramming drivers

plot_grouped_gene_trend(
    adata,
    stem_cell_tfs,
    group_key="group",
    layer="spliced",
    groups=["Hic2", "control"]
)

# %% [markdown]
# Jarid2, Tcf7l1, Rest and Tcf7l2 have the most interesting trends, but unlike the dead end drivers many only have differential expression later in during the process.

# %% [markdown]
# To do: Look at changes in transcription factor activity instead of mRNA levels. Below is a start for this

# %%
import gseapy as gp
import pandas as pd
import decoupler as dc

def load_enrichr_as_network(library_name):
    # 1. Download the library using GSEApy
    # Returns a dictionary: {'Term_Name': ['GeneA', 'GeneB', ...]}
    gs_dict = gp.get_library(name=library_name, organism='Mouse')
    
    network_list = []
    
    for term, genes in gs_dict.items():
        # The term usually looks like "KLF4 DOWN ..." or "KLF4_MOUSE_..."
        # We need to extract the TF name. 
        # CAUTION: This splitting depends on the specific naming convention of the library
        # For 'TF_Perturbations_Followed_by_Expression', format is often "TF_Perturbation_Direction"
        # We will attempt to grab the first word as the TF name
        if library_name in {"PerturbSeq_ReplogleK562", "PerturbSeq_ReplogleRPE1"}:
            tf_name = term.split()[1].upper()
        else:
            tf_name = term.split()[0].split('_')[0].upper() 
        
        for gene in genes:
            network_list.append({
                'source': tf_name,
                'target': gene,
                'weight': 1.0,      # We assume all targets are equal
                'collection': term  # Keep original term just in case
            })
            
    return pd.DataFrame(network_list)

# %%
# Use consensus network instead that also uses ChipSeq and motif data. Has Jarid in addition to the ones in TF_Perturbations_Followed_by_Expression,
# but gives values that do not work with Cellrank's gene_trends function
import decoupler as dc
net = dc.op.collectri(organism='mouse')

# %%
# Assuming 'adata' is your AnnData object
# remove duplicates just in case
net = net.drop_duplicates(['source', 'target'])

# Convert 'TARGET_GENE' -> 'Target_gene'
net['target'] = net['target'].str.capitalize()

# Optional: If you want the TF names (Source) to look like mouse TFs too
net['source'] = net['source'].str.capitalize()

# Run Activity Inference
# this fits a model for every cell to see if it expresses the TF targets
dc.mt.ulm(adata, net=net, verbose=True)

# The results are now in adata.obsm['ulm_estimate']
# Out:
# 2026-03-03 09:51:03 | [INFO] ulm - Running ulm
# 2026-03-03 09:51:03 | [INFO] Extracted omics mat with 12791 rows (observations) and 2000 columns (features)
# 2026-03-03 09:51:03 | [INFO] Network adjacency matrix has 1111 unique features and 459 unique sources
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-03-03 09:51:03 | [INFO] ulm - fitting 459 univariate models of 2000 observations (targets) with 1998 degrees of freedom
# 2026-03-03 09:51:04 | [INFO] ulm - adjusting p-values by FDR
# 2026-03-03 09:51:04 | [INFO] ulm - done

# %%
# Activity of interesting genes

plot_grouped_gene_trend(
    adata,
    ["Klf4", "Myc"],
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[171], line 3
#       1 # Activity of interesting genes
# ----> 3 plot_grouped_gene_trend(
#       4     adata,
#       5     ["Klf4", "Myc"],
#       6     group_key="group",
#       7     layer="score_ulm",
#       8     groups=["Hic2", "control"]
#       9 )
#
# Cell In[163], line 44, in plot_grouped_gene_trend(adata, genes, group_key, time_key, layer, groups, columns, figure_width, plot_height, n_splines)
#      42     expr_data = adata[:, gene].X
#      43 else:
# ---> 44     expr_data = adata[:, gene].layers[layer]
#      45 if hasattr(expr_data, "toarray"):
#      46     expr_data = expr_data.toarray()
#
# File ~/miniconda3/envs/single_cell/lib/python3.14/site-packages/anndata/_core/aligned_mapping.py:164, in AlignedView.__getitem__(self, key)
#     162 def __getitem__(self, key: str) -> Value:
#     163     return as_view(
# --> 164         _subset(self.parent_mapping[key], self.subset_idx),
#     165         ElementRef(self.parent, self.attrname, (key,)),
#     166     )
#
# File ~/miniconda3/envs/single_cell/lib/python3.14/site-packages/anndata/_core/aligned_mapping.py:215, in AlignedActual.__getitem__(self, key)
#     214 def __getitem__(self, key: str) -> Value:
# --> 215     return self._data[key]
#
# KeyError: 'score_ulm'

# %%
# Activity of dead end TFs

plot_grouped_gene_trend(
    adata,
    numpy.intersect1d(dead_end_tfs, adata.obsm["score_ulm"].columns),
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)

# %% [markdown]
# Ovol1 activity is surprisingly higher in Hic2 cells, despite much lower expression.

# %%
# Activity of reprogramming drivers

plot_grouped_gene_trend(
    adata,
    numpy.intersect1d(stem_cell_tfs, adata.obsm["score_ulm"].columns),
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)

# %% [markdown]
# Jarid2 and Zfp42 activities follow almost the exact same trends as their mRNA levels. They are similar until Hic2 and control cells start to take different trajectories. Rest has similar trends as its mRNA expression.

# %%
# Load another library
net = load_enrichr_as_network('TF_Perturbations_Followed_by_Expression') # Has the most genes because it is a collection
# Out:
# 2026-02-05 14:05:45 | [INFO] Downloading and generating Enrichr library gene sets...
# 2026-02-05 14:05:45 | [INFO] Library is already downloaded in: /home/avesta/m26_losu/.cache/gseapy/Enrichr.TF_Perturbations_Followed_by_Expression.gmt, use local file

# %%
# Assuming 'adata' is your AnnData object
# remove duplicates just in case
net = net.drop_duplicates(['source', 'target'])

# Convert 'TARGET_GENE' -> 'Target_gene'
net['target'] = net['target'].str.capitalize()

# Optional: If you want the TF names (Source) to look like mouse TFs too
net['source'] = net['source'].str.capitalize()

# Run Activity Inference
# this fits a model for every cell to see if it expresses the TF targets
dc.mt.ulm(adata, net=net, verbose=True)

# The results are now in adata.obsm['ulm_estimate']
# Out:
# 2026-02-05 14:05:46 | [INFO] ulm - Running ulm
# 2026-02-05 14:05:46 | [INFO] Extracted omics mat with 12791 rows (observations) and 2000 columns (features)
# 2026-02-05 14:05:46 | [INFO] Network adjacency matrix has 1749 unique features and 342 unique sources
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-02-05 14:05:46 | [INFO] ulm - fitting 342 univariate models of 2000 observations (targets) with 1998 degrees of freedom
# 2026-02-05 14:05:48 | [INFO] ulm - adjusting p-values by FDR
# 2026-02-05 14:05:48 | [INFO] ulm - done

# %%
# Activity of interesting genes

plot_grouped_gene_trend(
    adata,
    ["Klf4", "Myc", "Tp53"],
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)

# %%
# Activity of dead end TFs

plot_grouped_gene_trend(
    adata,
    numpy.intersect1d(dead_end_tfs, adata.obsm["score_ulm"].columns),
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)

# %%
# Activity of reprogramming drivers

plot_grouped_gene_trend(
    adata,
    numpy.intersect1d(stem_cell_tfs, adata.obsm["score_ulm"].columns),
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)

# %%
# Cellrank gene trends for dead end

import scanpy as sc
import cellrank as cr

def plot_tf_trends(adata, tfs, time_key, model=None, group_key="group"):
    """
    Plots Decoupler TF activity scores using CellRank's gene_trends.
    """
    # Extract the ULM scores (Cell x TF matrix)
    activity_matrix = adata.obsm['score_ulm'].copy()
    
    # Create a new temporary AnnData object
    # The 'variables' (var) of this object are the TFs, not genes
    tf_adata = sc.AnnData(activity_matrix)
    tf_adata.obs = adata.obs.copy()  # Copy metadata (pseudotime, clusters)
    tf_adata.obsm = adata.obsm.copy() # Copy embeddings (UMAP) and lineage probs
    tf_adata.uns = adata.uns.copy()   # Copy CellRank lineage colors/names
    
    # Setup the CellRank model if not provided
    if model is None:
        model = cr.models.GAMR(tf_adata)
        
    # Plot using the standard function
    cellrank.pl.gene_trends(
    tf_adata,
    model=model,
    genes=tfs,
    data_key="X",
    same_plot=True,
    lineages = ["mESC", "Day 12 Control"],
    ncols=4,
    time_key=time_key,
    hide_cells=True,
    weight_threshold=(1e-3, 1e-3),
)

# %%
plot_tf_trends(
    adata, 
    tfs=numpy.intersect1d(["Klf4", "Myc", "Tp53"], adata.obsm["score_ulm"].columns), 
    time_key='latent_time'
)
# Out:
# 2026-02-05 14:05:49 | [INFO] cffi mode is CFFI_MODE.ANY
# 2026-02-05 14:05:50 | [INFO] R home found: /home/avesta/m26_losu/miniconda3/envs/velocity/lib/R
# 2026-02-05 14:05:50 | [INFO] R library path:
# 2026-02-05 14:05:50 | [INFO] LD_LIBRARY_PATH:
# 2026-02-05 14:05:50 | [INFO] Default options to initialize R: rpy2, --quiet, --no-save
# 2026-02-05 14:05:50 | [INFO] Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/avesta/m26_losu", R: "/home/avesta/m26_losu/hic2_masters_project"
# 2026-02-05 14:05:51 | [INFO] R is already initialized. No need to initialize.
#   0%|          | 0/3 [00:00<?, ?gene/s]

# %%
plot_tf_trends(
    adata, 
    tfs=numpy.intersect1d(dead_end_tfs, adata.obsm["score_ulm"].columns), 
    time_key='latent_time'
)
# Out:
#   0%|          | 0/2 [00:00<?, ?gene/s]

# %%
# Cellrank gene trends for stem cells

plot_tf_trends(
    adata, 
    tfs=numpy.intersect1d(stem_cell_tfs, adata.obsm["score_ulm"].columns), 
    time_key='latent_time' # or 'dpt_pseudotime'
)
# Out:
#   0%|          | 0/5 [00:00<?, ?gene/s]

# %% [markdown]
# Zfp42 activity is interesting, as it increases in the mESC cells. The other genes do not look like clear reprogramming drivers.

# %%
# A library from CRISPR screen
net = load_enrichr_as_network('PerturbSeq_ReplogleK562')

# Assuming 'adata' is your AnnData object
# remove duplicates just in case
net = net.drop_duplicates(['source', 'target'])

# Convert 'TARGET_GENE' -> 'Target_gene'
net['target'] = net['target'].str.capitalize()

# Optional: If you want the TF names (Source) to look like mouse TFs too
net['source'] = net['source'].str.capitalize()

# Run Activity Inference
# this fits a model for every cell to see if it expresses the TF targets
dc.mt.ulm(adata, net=net, verbose=True)

# The results are now in adata.obsm['ulm_estimate']
# Out:
# 2026-02-05 14:05:56 | [INFO] Downloading and generating Enrichr library gene sets...
# 2026-02-05 14:06:05 | [INFO] ulm - Running ulm
# 2026-02-05 14:06:05 | [INFO] Extracted omics mat with 12791 rows (observations) and 2000 columns (features)
# 2026-02-05 14:06:06 | [INFO] Network adjacency matrix has 499 unique features and 1477 unique sources
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-02-05 14:06:06 | [INFO] ulm - fitting 1477 univariate models of 2000 observations (targets) with 1998 degrees of freedom
# 2026-02-05 14:06:10 | [INFO] ulm - adjusting p-values by FDR
# 2026-02-05 14:06:10 | [INFO] ulm - done

# %%
# Activity of dead end TFs

plot_grouped_gene_trend(
    adata,
    numpy.intersect1d(dead_end_tfs, adata.obsm["score_ulm"].columns),
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)

# %%
# Activity of reprogramming drivers

plot_grouped_gene_trend(
    adata,
    numpy.intersect1d(stem_cell_tfs, adata.obsm["score_ulm"].columns),
    group_key="group",
    obsm=True,
    layer="score_ulm",
    groups=["Hic2", "control"]
)

# %% [markdown]
# # Conclusions
#
# The most important target of Hic2 is Ovol1. It downregulates c-Myc (https://www.nature.com/articles/modpathol2016169) and inhibits the epithelial to mesenchymal transition by degrading the TGF-β receptor type 1 while promoting mesenchymal-to-epithelial transition (https://www.nature.com/articles/s41392-022-00944-w).
